# %%
# !pip install faiss-cpu

import faiss
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.11/dist-packages (1.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)

# %%
# !pip uninstall transformers
# Out:
# Found existing installation: transformers 4.51.3
# Uninstalling transformers-4.51.3:
#   Would remove:
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.11/dist-packages/transformers-4.51.3.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/transformers/*
# Proceed (Y/n)? n

# %%
import pandas as pd
import torch
import numpy as np
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# Load E5-large model
# model = SentenceTransformer('intfloat/e5-large')
# model = SentenceTransformer("moka-ai/m3e-base")
model = SentenceTransformer("all-mpnet-base-v2")

# model = SentenceTransformer("BAAI/bge-base-en-v1.5")
model = model.to(device)

# -----------------------------
# LOAD PRODUCT CATALOG
# -----------------------------
catalog_df = pd.read_csv("/content/drive/MyDrive/Zepto IDC Query Classification/Zepto Data Challenge_ Intent prediction - catalog.csv")
catalog_df = catalog_df.drop_duplicates(subset=["product_variant_id"])

# -----------------------------
# LOAD LABELED SEARCH DATASET
# -----------------------------
labeled_df = pd.read_csv("/content/drive/MyDrive/Zepto IDC Query Classification/Zepto Data Challenge_ Intent prediction - labelled_data.csv")
# Out:
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
labeled_df
# Out:
#                         search_term  \
# 0                        atta maggi
# 1            bombay shaving company
# 2                       choco fills
# 3                            chocos
# 4                   epigamia yogurt
# ...                             ...
# 10830      colgate small toothpaste
# 10831  colgate whitening toothpaste
# 10832                  cologne mask
# 10833                      color fx
# 10834             colored a4 sheets
#
#                                                 l1_preds  \
# 0                                      ["Packaged Food"]
# 1      ["Electronics & Appliances","Feminine Hygiene"...
# 2      ["Biscuits","Sweet Cravings","Breakfast & Sauc...
# 3      ["Biscuits","Sweet Cravings","Breakfast & Sauc...
# 4         ["Cold Drinks & Juices","Dairy, Bread & Eggs"]
# ...                                                  ...
# 10830                                    ["Bath & Body"]
# 10831                                    ["Bath & Body"]
# 10832  ["Fragrances & Grooming","Skincare","Apparel &...
# 10833        ["Makeup & Beauty","Fragrances & Grooming"]
# 10834                             ["Stationery & Books"]
#
#                                                 l2_preds  \
# 0                               ["Noodles & Vermicelli"]
# 1      ["Grooming","Hair Removal For Women","Shaving ...
# 2      ["Chocolates","Breakfast Cereals","Creamfills"...
# 3      ["Cookies","Pastries & Cakes","Breakfast Cerea...
# 4                       ["Milk Drinks","Yogurts & Dahi"]
# ...                                                  ...
# 10830                         ["Toothpaste & Mouthwash"]
# 10831                         ["Toothpaste & Mouthwash"]
# 10832  ["Perfumes","Face Care","Travel Accessories","...
# 10833  ["Face Makeup","Hygiene Essentials","Nails","G...
# 10834               ["Crafts & Hobby","School Supplies"]
#
#                                                 l3_preds
# 0                           ["Instant Noodles","Bundle"]
# 1      ["Trimmer","Razor","Shaving Cream","Face Wash"...
# 2      ["Wafer Chocolates","Kids' Cereal","Centre Fil...
# 3                           ["Choco Pie","Kids' Cereal"]
# 4                          ["Smoothie","Dahi","Yogurts"]
# ...                                                  ...
# 10830                                     ["Toothpaste"]
# 10831                                     ["Toothpaste"]
# 10832  ["Body Perfume","Neck Pillow","Sheet Mask","Un...
# 10833  ["Nail Polish Remover","Makeup Remover","Nail ...
# 10834                   ["Craft paper","Scribble Paper"]
#
# [10835 rows x 4 columns]

# %%
import pandas as pd
import ast

# %%
def flatten_for_finetuning(df):
    rows = []
    for _, row in df.iterrows():
        query = row['search_term']

        for l1 in ast.literal_eval(row['l1_preds']):
            rows.append({'input_text': f"L1: {query}", 'target_text': l1})

        for l2 in ast.literal_eval(row['l2_preds']):
            rows.append({'input_text': f"L2: {query}", 'target_text': l2})

        for l3 in ast.literal_eval(row['l3_preds']):
            rows.append({'input_text': f"L3: {query}", 'target_text': l3})

    return pd.DataFrame(rows)

finetune_df = flatten_for_finetuning(labeled_df)
finetune_df.to_csv("finetune_input.csv", index=False)
print(finetune_df.head())
# Out:
#                    input_text               target_text
# 0              L1: atta maggi             Packaged Food
# 1              L2: atta maggi      Noodles & Vermicelli
# 2              L3: atta maggi           Instant Noodles
# 3              L3: atta maggi                    Bundle
# 4  L1: bombay shaving company  Electronics & Appliances

# %%
from random import sample

def make_pair_samples(df, level, num_negatives=2):
    df = df[df['input_text'].str.startswith(level + ":")].copy()
    df['query'] = df['input_text'].apply(lambda x: x.split(":")[1].strip())

    # Group all valid categories per query
    group = df.groupby('query')['target_text'].apply(list).to_dict()

    all_categories = set(df['target_text'].unique())
    pair_data = []

    for query, pos_categories in group.items():
        # Positive samples
        for pos_cat in pos_categories:
            pair_data.append({
                'query': query,
                'category': pos_cat,
                'label': 1.0
            })

        # Negative samples
        negatives = list(all_categories - set(pos_categories))
        sampled_negs = sample(negatives, min(num_negatives * len(pos_categories), len(negatives)))
        for neg_cat in sampled_negs:
            pair_data.append({
                'query': query,
                'category': neg_cat,
                'label': 0.0
            })

    return pair_data

# %%
l1_samples = make_pair_samples(finetune_df, level="L1", num_negatives=2)
l1_samples[:6]  # show a few sample pairs
# Out:
# [{'query': '0 calorie drink',
#   'category': 'Cold Drinks & Juices',
#   'label': 1.0},
#  {'query': '0 calorie drink',
#   'category': 'Fruits  & Vegetables',
#   'label': 0.0},
#  {'query': '0 calorie drink', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '0aneer', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '0aneer', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '0aneer', 'category': 'Sexual Wellness', 'label': 0.0}]

# %%
l1_samples
# Out:
# [{'query': '0 calorie drink',
#   'category': 'Cold Drinks & Juices',
#   'label': 1.0},
#  {'query': '0 calorie drink',
#   'category': 'Fruits  & Vegetables',
#   'label': 0.0},
#  {'query': '0 calorie drink', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '0aneer', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '0aneer', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '0aneer', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '0ni', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '0ni', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '0ni', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '0ni', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '0ni', 'category': 'Electronics & Appliances', 'label': 0.0},
#  {'query': '0ni', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '1 inch tape', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '1 inch tape', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '1 inch tape', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1 inch tape', 'category': 'Makeup & Beauty', 'label': 1.0},
#  {'query': '1 inch tape',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Kitchen & Dining', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '1 inch tape', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '1 kg chai patti', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1 kg chai patti', 'category': 'Tea, Coffee & More', 'label': 1.0},
#  {'query': '1 kg chai patti', 'category': 'Pet Care', 'label': 1.0},
#  {'query': '1 kg chai patti', 'category': 'Ice Creams & More', 'label': 1.0},
#  {'query': '1 kg chai patti',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '1 kg chai patti', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '1 kg chai patti', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '1 kg chai patti',
#   'category': 'Fruits  & Vegetables',
#   'label': 0.0},
#  {'query': '1 kg chai patti', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '1 kg chai patti', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '1 kg chai patti', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '1 kg chai patti', 'category': 'Munchies', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1 kg fish', 'category': 'Masala, Dry Fruits & More', 'label': 1.0},
#  {'query': '1 kg fish', 'category': 'Pet Care', 'label': 1.0},
#  {'query': '1 kg fish', 'category': 'Frozen Food', 'label': 1.0},
#  {'query': '1 kg fish', 'category': 'Meats, Fish & Eggs', 'label': 1.0},
#  {'query': '1 kg fish', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '1 kg fish', 'category': 'Cold Drinks & Juices', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Electronics & Appliances', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Atta, Rice, Oil & Dals', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '1 kg fish', 'category': 'Kitchen & Dining', 'label': 0.0},
#  {'query': '1 kg haldiram', 'category': 'Munchies', 'label': 1.0},
#  {'query': '1 kg haldiram', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '1 kg haldiram', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '1 kg honey', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1 kg honey', 'category': 'Breakfast & Sauces', 'label': 1.0},
#  {'query': '1 kg honey', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '1 kg honey', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '1 kg honey', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '1 kg honey', 'category': 'Cold Drinks & Juices', 'label': 0.0},
#  {'query': '1 kg milk', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '1 kg milk', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '1 kg milk', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '1 kg potato', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '1 kg potato',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '1 kg potato', 'category': 'Skincare', 'label': 0.0},
#  {'query': '1 kilo chicken', 'category': 'Meats, Fish & Eggs', 'label': 1.0},
#  {'query': '1 kilo chicken', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1 kilo chicken', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '1 kilo chicken', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '1 kilo chicken', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '1 kilo chicken', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '1 l amul milk', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '1 l amul milk',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '1 l amul milk',
#   'category': 'Atta, Rice, Oil & Dals',
#   'label': 0.0},
#  {'query': '1 lit', 'category': 'Toys & Sports', 'label': 1.0},
#  {'query': '1 lit', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '1 lit', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '1 lit', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '1 lit', 'category': 'Zepto Cafe', 'label': 0.0},
#  {'query': '1 lit', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '1 lit', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '1 lit', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '1 lit', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '1 lit', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '1 lit', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '1 lit', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '1 liter curd', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '1 liter curd', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1 liter curd', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '1 liter curd', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '1 liter curd', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '1 liter curd',
#   'category': 'Masala, Dry Fruits & More',
#   'label': 0.0},
#  {'query': '1 litre amul milk',
#   'category': 'Dairy, Bread & Eggs',
#   'label': 1.0},
#  {'query': '1 litre amul milk', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '1 litre amul milk',
#   'category': 'Breakfast & Sauces',
#   'label': 0.0},
#  {'query': '1 litre dahi', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '1 litre dahi',
#   'category': 'Electronics & Appliances',
#   'label': 1.0},
#  {'query': '1 litre dahi', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '1 litre dahi', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '1 litre dahi', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '1 litre dahi',
#   'category': 'Masala, Dry Fruits & More',
#   'label': 0.0},
#  {'query': '1 tray egg', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '1 tray egg', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '1 tray egg', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 ch', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '10 ch', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '10 ch', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '10 ch', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '10 ch', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '10 ch', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Skincare', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Electronics & Appliances', 'label': 0.0},
#  {'query': '10 ch', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '10 curd', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '10 curd', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 curd', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '10 curd', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '10 curd', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '10 curd', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '10 kg aata', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '10 kg aata', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 kg aata', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '10 kg aata', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '10 kg aata', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '10 kg aata', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '10 l bag', 'category': 'Apparel & Lifestyle', 'label': 1.0},
#  {'query': '10 l bag', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '10 l bag', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 l bag', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '10 l bag', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '10 l bag', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '10 l bag', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '10 l bag', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '10 l bag', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '10 liter water can', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 liter water can', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '10 liter water can',
#   'category': 'Cold Drinks & Juices',
#   'label': 1.0},
#  {'query': '10 liter water can',
#   'category': 'Breakfast & Sauces',
#   'label': 0.0},
#  {'query': '10 liter water can',
#   'category': 'Stationery & Books',
#   'label': 0.0},
#  {'query': '10 liter water can',
#   'category': 'Ice Creams & More',
#   'label': 0.0},
#  {'query': '10 liter water can',
#   'category': 'Tea, Coffee & More',
#   'label': 0.0},
#  {'query': '10 liter water can', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '10 liter water can', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '10 liters water', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '10 liters water', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 liters water',
#   'category': 'Cold Drinks & Juices',
#   'label': 1.0},
#  {'query': '10 liters water', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '10 liters water', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '10 liters water', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '10 liters water', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '10 liters water',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '10 liters water', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '10 liters water bottle',
#   'category': 'Kitchen & Dining',
#   'label': 1.0},
#  {'query': '10 liters water bottle',
#   'category': 'Cold Drinks & Juices',
#   'label': 1.0},
#  {'query': '10 liters water bottle', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '10 liters water bottle',
#   'category': 'Feminine Hygiene',
#   'label': 0.0},
#  {'query': '10 liters water bottle',
#   'category': 'Stationery & Books',
#   'label': 0.0},
#  {'query': '10 liters water bottle',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '10 litre water', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '10 litre water', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 litre water', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '10 litre water', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '10 litre water', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '10 litre water',
#   'category': 'Fragrances & Grooming',
#   'label': 0.0},
#  {'query': '10 litre water', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '10 litre water', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '10 litre water', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '10 litter', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 litter', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '10 litter', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '10 litter', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '10 litter', 'category': 'Atta, Rice, Oil & Dals', 'label': 0.0},
#  {'query': '10 litter', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '10 lwater', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 lwater', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '10 lwater', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '10 lwater', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '10 lwater', 'category': 'Munchies', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Atta, Rice, Oil & Dals', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '10 lwater', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Munchies', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Paan Corner', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Feminine Hygiene', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Toys & Sports', 'label': 1.0},
#  {'query': '10 pack', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Skincare', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '10 pack',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '10 pack', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Atta, Rice, Oil & Dals', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '10 pack', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '10 pen', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '10 pen',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '10 pen', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '10 rs biscuit', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '10 rs biscuit', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '10 rs biscuit', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '10 rs cake', 'category': 'Sweet Cravings', 'label': 1.0},
#  {'query': '10 rs cake', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 rs cake', 'category': 'Kitchen & Dining', 'label': 0.0},
#  {'query': '10 rs cake', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '10 rs cake', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '10 rs cake', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '10 rs oreo', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '10 rs oreo', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '10 rs oreo', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '10 rupee dairy milk', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 rupee dairy milk', 'category': 'Sweet Cravings', 'label': 1.0},
#  {'query': '10 rupee dairy milk',
#   'category': 'Breakfast & Sauces',
#   'label': 0.0},
#  {'query': '10 rupee dairy milk',
#   'category': 'Ice Creams & More',
#   'label': 0.0},
#  {'query': '10 rupee dairy milk',
#   'category': 'Meats, Fish & Eggs',
#   'label': 0.0},
#  {'query': '10 rupee dairy milk', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '10 rupees snacks', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10 rupees snacks', 'category': 'Munchies', 'label': 1.0},
#  {'query': '10 rupees snacks',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '10 rupees snacks', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '10 rupees snacks', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '10 rupees snacks', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '10 snacks', 'category': 'Munchies', 'label': 1.0},
#  {'query': '10 snacks', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '10 snacks', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '100 gsm paper', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '100 gsm paper', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '100 gsm paper', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '1008 rice', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1008 rice', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '1008 rice', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '1008 rice', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '1008 rice', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '1008 rice', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '100g panner', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '100g panner', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '100g panner', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '100g panner', 'category': 'Cold Drinks & Juices', 'label': 0.0},
#  {'query': '100g panner', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '100g panner',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '10rs snacks', 'category': 'Munchies', 'label': 1.0},
#  {'query': '10rs snacks', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '10rs snacks', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '10rs snacks', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '10rs snacks', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '10rs snacks', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '12 rules of life', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '12 rules of life', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '12 rules of life', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '120 pages notebook',
#   'category': 'Stationery & Books',
#   'label': 1.0},
#  {'query': '120 pages notebook', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '120 pages notebook',
#   'category': 'Grooming Essentials',
#   'label': 0.0},
#  {'query': '13 mini', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '13 mini', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '13 mini', 'category': 'Munchies', 'label': 0.0},
#  {'query': '13 mini', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '13 mini', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '13 mini', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '15 kg oli', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '15 kg oli', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '15 kg oli', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '15 kg oli', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '15 kg oli', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '15 l', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '15 l', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '15 l', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '15 l', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '15 l', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '15 l', 'category': 'Apparel & Lifestyle', 'label': 1.0},
#  {'query': '15 l', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '15 l', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '15 l', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '15 l', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '15 l', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '15 l', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '15 l', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '15 l', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '15 l', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '15 l', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '15 l', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '15 l', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '15 l', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '15 l', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '15 l', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '15 l',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '15 l', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '15 l', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '15 litar', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '15 litar', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '15 litar', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '15 litar', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '15 litar', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '15 litar', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '15 liter oil can',
#   'category': 'Atta, Rice, Oil & Dals',
#   'label': 1.0},
#  {'query': '15 liter oil can', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '15 liter oil can', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '15 liter oil can',
#   'category': 'Fragrances & Grooming',
#   'label': 0.0},
#  {'query': '15 liter oil can',
#   'category': 'Cleaning Essentials',
#   'label': 0.0},
#  {'query': '15 liter oil can',
#   'category': 'Cold Drinks & Juices',
#   'label': 0.0},
#  {'query': '15 liter oil can',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '15 liter oil can',
#   'category': 'Masala, Dry Fruits & More',
#   'label': 0.0},
#  {'query': '15 liter oil can', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '15 ltr', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '15 ltr', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '15 ltr', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '15 ltr', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '15 ltr', 'category': 'Apparel & Lifestyle', 'label': 1.0},
#  {'query': '15 ltr', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Atta, Rice, Oil & Dals', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Skincare', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '15 ltr', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '15kg oli', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '15kg oli', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '15kg oli', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '15kg oli', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Skincare', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '15kg oli', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '1984', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '1984', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '1984',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '1kg bhujiya', 'category': 'Munchies', 'label': 1.0},
#  {'query': '1kg bhujiya', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1kg bhujiya', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '1kg bhujiya', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '1kg bhujiya', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '1kg bhujiya', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Toys & Sports', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Ice Creams & More', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Masala, Dry Fruits & More', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Breakfast & Sauces', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Tea, Coffee & More', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '1kg bis', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '1kg bis',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '1kg bis', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Skincare', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Munchies', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Cold Drinks & Juices', 'label': 0.0},
#  {'query': '1kg bis', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '1kg biscuits', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '1kg biscuits', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '1kg biscuits', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '1kg butter', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1kg butter', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '1kg butter', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '1kg butter', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '1kg butter', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '1kg butter', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '1kg namkin', 'category': 'Munchies', 'label': 1.0},
#  {'query': '1kg namkin', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1kg namkin', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '1kg namkin', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '1kg namkin', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '1kg namkin', 'category': 'Skincare', 'label': 0.0},
#  {'query': '1kg surfexcel', 'category': 'Cleaning Essentials', 'label': 1.0},
#  {'query': '1kg surfexcel', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '1kg surfexcel', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '1kg sweet', 'category': 'Masala, Dry Fruits & More', 'label': 1.0},
#  {'query': '1kg sweet', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '1kg sweet', 'category': 'Sweet Cravings', 'label': 1.0},
#  {'query': '1kg sweet', 'category': 'Munchies', 'label': 1.0},
#  {'query': '1kg sweet', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '1kg sweet', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '1kg sweet', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '1kg sweet',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '1kg sweet', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '1kg sweet', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '1kg sweet', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '1kg sweet', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '2 in 1 tape', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '2 in 1 tape', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '2 in 1 tape', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '2 in 1 tape', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '2 in 1 tape', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '2 in 1 tape', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '2 l thumbs up', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '2 l thumbs up', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '2 l thumbs up', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '2 lt', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '2 lt',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '2 lt', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '2 ltr milk', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '2 ltr milk', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '2 ltr milk', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '2 maggi', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '2 maggi', 'category': 'Packaged Food', 'label': 1.0},
#  {'query': '2 maggi', 'category': 'Cold Drinks & Juices', 'label': 0.0},
#  {'query': '2 maggi', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '2 maggi', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '2 maggi', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '2 yum', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '2 yum', 'category': 'Munchies', 'label': 1.0},
#  {'query': '2 yum', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '2 yum', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '2 yum', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '2 yum', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '20 coke', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '20 coke', 'category': 'Zepto Cafe', 'label': 0.0},
#  {'query': '20 coke', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '20 liter jar', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '20 liter jar',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '20 liter jar', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '20 rs drink', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '20 rs drink', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '20 rs drink', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '20 rs drink', 'category': 'Skincare', 'label': 0.0},
#  {'query': '20 rs drink', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '20 rs drink', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '20 rupees coke', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '20 rupees coke', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '20 rupees coke', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '20 rupees coke',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '20 rupees coke', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '20 rupees coke', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '20 rupees lays', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '20 rupees lays', 'category': 'Munchies', 'label': 1.0},
#  {'query': '20 rupees lays', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '20 rupees lays', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '20 rupees lays',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '20 rupees lays', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '20 ruppes chips', 'category': 'Munchies', 'label': 1.0},
#  {'query': '20 ruppes chips', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '20 ruppes chips', 'category': 'Skincare', 'label': 0.0},
#  {'query': '20 wali chips', 'category': 'Munchies', 'label': 1.0},
#  {'query': '20 wali chips', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '20 wali chips',
#   'category': 'Atta, Rice, Oil & Dals',
#   'label': 0.0},
#  {'query': '200 g curd', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '200 g curd', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '200 g curd', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '200 g curd', 'category': 'Electronics & Appliances', 'label': 0.0},
#  {'query': '200 g curd', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '200 g curd', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '200 pages long note book',
#   'category': 'Stationery & Books',
#   'label': 1.0},
#  {'query': '200 pages long note book',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '200 pages long note book',
#   'category': 'Toys & Sports',
#   'label': 0.0},
#  {'query': '200ml bottle', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '200ml bottle', 'category': 'Makeup & Beauty', 'label': 1.0},
#  {'query': '200ml bottle', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '200ml bottle', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '200ml bottle', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '200ml bottle', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '200ml bottle', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '200ml bottle', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '200ml bottle', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '2025 planner', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '2025 planner', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '2025 planner', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '20litre', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '20litre', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '20litre', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '20litre', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '20litre', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '20litre', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '20litre', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '20litre', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '20litre', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '20litre',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '20litre', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '20litre', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '24 shades', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '24 shades', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '24 shades', 'category': 'Electronics & Appliances', 'label': 0.0},
#  {'query': '25 birthday', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '25 birthday', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '25 birthday', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '25 birthday', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '25 birthday', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '25 birthday', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '25 rupees item', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '25 rupees item', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '25 rupees item', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '250 gram cake', 'category': 'Sweet Cravings', 'label': 1.0},
#  {'query': '250 gram cake', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '250 gram cake', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '250 gram cake', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '250 gram cake', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '250 gram cake',
#   'category': 'Masala, Dry Fruits & More',
#   'label': 0.0},
#  {'query': '250 ml drink', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '250 ml drink', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '250 ml drink', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '250 ml drink', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '250 ml drink', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '250 ml drink', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '250gm paneer', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '250gm paneer', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '250gm paneer', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '250gm paneer', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '250gm paneer', 'category': 'Munchies', 'label': 0.0},
#  {'query': '250gm paneer', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '26 rice', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '26 rice', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '26 rice', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '26 rice', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '26 rice', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '26 rice', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '2hb pencil', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '2hb pencil', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '2hb pencil', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '2kg container', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '2kg container', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '2kg container', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '2kg milk', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '2kg milk', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '2kg milk', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '2kg sug', 'category': 'Masala, Dry Fruits & More', 'label': 1.0},
#  {'query': '2kg sug', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '2kg sug', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '2kg sug', 'category': 'Tea, Coffee & More', 'label': 1.0},
#  {'query': '2kg sug', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '2kg sug', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '2kg tide', 'category': 'Cleaning Essentials', 'label': 1.0},
#  {'query': '2kg tide', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '2kg tide', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '2l coca cola', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '2l coca cola',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '2l coca cola', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '2l cold', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '2l cold', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '2l cold', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '2l cold', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '2l cold', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '2l cold', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '2m dark compound chocolate',
#   'category': 'Sweet Cravings',
#   'label': 1.0},
#  {'query': '2m dark compound chocolate',
#   'category': 'Zepto Cafe',
#   'label': 1.0},
#  {'query': '2m dark compound chocolate',
#   'category': 'Breakfast & Sauces',
#   'label': 0.0},
#  {'query': '2m dark compound chocolate',
#   'category': 'Meats, Fish & Eggs',
#   'label': 0.0},
#  {'query': '2m dark compound chocolate',
#   'category': 'Stationery & Books',
#   'label': 0.0},
#  {'query': '2m dark compound chocolate',
#   'category': 'Packaged Food',
#   'label': 0.0},
#  {'query': '2ply towels', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '2ply towels', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '2ply towels', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '2ply towels',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '2ply towels', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '2ply towels', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '2x spice', 'category': 'Breakfast & Sauces', 'label': 1.0},
#  {'query': '2x spice', 'category': 'Packaged Food', 'label': 1.0},
#  {'query': '2x spice', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '2x spice', 'category': 'Skincare', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Atta, Rice, Oil & Dals', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Kitchen & Dining', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '2x spice', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '2x spicy ramen', 'category': 'Packaged Food', 'label': 1.0},
#  {'query': '2x spicy ramen', 'category': 'Skincare', 'label': 0.0},
#  {'query': '2x spicy ramen', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '2xl', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '2xl', 'category': 'Apparel & Lifestyle', 'label': 1.0},
#  {'query': '2xl',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '2xl', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '2xl', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '2xl', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '3 litre', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '3 litre', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '3 litre', 'category': 'Cleaning Essentials', 'label': 1.0},
#  {'query': '3 litre', 'category': 'Cold Drinks & Juices', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '3 litre', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '3 litre pressure cooker',
#   'category': 'Kitchen & Dining',
#   'label': 1.0},
#  {'query': '3 litre pressure cooker', 'category': 'Munchies', 'label': 0.0},
#  {'query': '3 litre pressure cooker', 'category': 'Skincare', 'label': 0.0},
#  {'query': '3 mangoes', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '3 mangoes', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '3 mangoes', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '3 mangoes', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '3 mangoes', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '3 mangoes', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '3 mangoes', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '3 mangoes', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '3 mangoes', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '3 min poha', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '3 min poha', 'category': 'Packaged Food', 'label': 1.0},
#  {'query': '3 min poha', 'category': 'Zepto Cafe', 'label': 1.0},
# ...
#  {'query': '5 let', 'category': 'Apparel & Lifestyle', 'label': 0.0},
#  {'query': '5 letter oil', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '5 letter oil', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5 letter oil', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '5 letter oil', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '5 letter oil', 'category': 'Kitchen & Dining', 'label': 0.0},
#  {'query': '5 letter oil', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '5 line notebook', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '5 line notebook',
#   'category': 'Fruits  & Vegetables',
#   'label': 0.0},
#  {'query': '5 line notebook', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '5 litar', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5 litar', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '5 litar', 'category': 'Cleaning Essentials', 'label': 1.0},
#  {'query': '5 litar', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '5 litar', 'category': 'Baby Care', 'label': 1.0},
#  {'query': '5 litar', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '5 litar', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Munchies', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '5 litar',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '5 litar', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Electronics & Appliances', 'label': 0.0},
#  {'query': '5 litar', 'category': 'Skincare', 'label': 0.0},
#  {'query': '5 liter container', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '5 liter container', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5 liter container',
#   'category': 'Grooming Essentials',
#   'label': 0.0},
#  {'query': '5 liter container', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '5 liter container', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '5 liter container',
#   'category': 'Cold Drinks & Juices',
#   'label': 0.0},
#  {'query': '5 litre refined',
#   'category': 'Atta, Rice, Oil & Dals',
#   'label': 1.0},
#  {'query': '5 litre refined', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5 litre refined', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '5 litre refined', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '5 litre refined',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '5 litre refined', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '5 munch', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5 munch', 'category': 'Sweet Cravings', 'label': 1.0},
#  {'query': '5 munch', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '5 munch', 'category': 'Kitchen & Dining', 'label': 0.0},
#  {'query': '5 munch', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '5 munch', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '50 50 bisket', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '50 50 bisket', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '50 50 bisket', 'category': 'Munchies', 'label': 0.0},
#  {'query': '50 50 maska chaska', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '50 50 maska chaska', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '50 50 maska chaska', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '50 50 maska chaska',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '50 50 maska chaska',
#   'category': 'Meats, Fish & Eggs',
#   'label': 0.0},
#  {'query': '50 50 maska chaska',
#   'category': 'Dairy, Bread & Eggs',
#   'label': 0.0},
#  {'query': '50 kg sugar', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '50 kg sugar',
#   'category': 'Masala, Dry Fruits & More',
#   'label': 1.0},
#  {'query': '50 kg sugar', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '50 kg sugar', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '50 kg sugar', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '50 kg sugar', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '50 wala pizza', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '50 wala pizza', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '50 wala pizza', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '50 wala pizza',
#   'category': 'Atta, Rice, Oil & Dals',
#   'label': 0.0},
#  {'query': '50 wala pizza', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '50 wala pizza', 'category': 'Cold Drinks & Juices', 'label': 0.0},
#  {'query': '500 gm potato', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '500 gm potato', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '500 gm potato', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '500 gm potato', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '500 gm potato', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '500 gm potato',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '500 gram cake', 'category': 'Ice Creams & More', 'label': 1.0},
#  {'query': '500 gram cake', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '500 gram cake', 'category': 'Sweet Cravings', 'label': 1.0},
#  {'query': '500 gram cake', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '500 gram cake', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '500 gram cake', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '500 gram cake', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '500 gram cake', 'category': 'Cleaning Essentials', 'label': 0.0},
#  {'query': '500 gram cake', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '500 ml flask', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '500 ml flask', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '500 ml flask', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '500 ml flask', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '500 ml flask', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '500 ml flask', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '500 pages book', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '500 pages book', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '500 pages book', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '500ml water bottle', 'category': 'Toys & Sports', 'label': 1.0},
#  {'query': '500ml water bottle', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '500ml water bottle', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '500ml water bottle', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '500ml water bottle',
#   'category': 'Fruits  & Vegetables',
#   'label': 0.0},
#  {'query': '500ml water bottle',
#   'category': 'Tea, Coffee & More',
#   'label': 0.0},
#  {'query': '50w led bulb',
#   'category': 'Electronics & Appliances',
#   'label': 1.0},
#  {'query': '50w led bulb', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '50w led bulb', 'category': 'Zepto Cafe', 'label': 0.0},
#  {'query': '50w led bulb', 'category': 'Pharma & Wellness', 'label': 0.0},
#  {'query': '50w led bulb', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '50w led bulb',
#   'category': 'Masala, Dry Fruits & More',
#   'label': 0.0},
#  {'query': '55', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '55', 'category': 'Munchies', 'label': 1.0},
#  {'query': '55', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '55', 'category': 'Stationery & Books', 'label': 0.0},
#  {'query': '55', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '55', 'category': 'Zepto Cafe', 'label': 0.0},
#  {'query': '555 sabun', 'category': 'Bath & Body', 'label': 1.0},
#  {'query': '555 sabun', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '555 sabun', 'category': 'Skincare', 'label': 0.0},
#  {'query': '5g phones', 'category': 'Electronics & Appliances', 'label': 1.0},
#  {'query': '5g phones', 'category': 'Munchies', 'label': 1.0},
#  {'query': '5g phones', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '5g phones', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '5g phones', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '5g phones', 'category': 'Skincare', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Hair Care', 'label': 1.0},
#  {'query': '5l oi', 'category': 'Baby Care', 'label': 1.0},
#  {'query': '5l oi', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '5l oi', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '5l oi', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '5l oi', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '5l oi', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Breakfast & Sauces', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '5l oi', 'category': 'Fruits & Vegetables', 'label': 0.0},
#  {'query': '5l water', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5l water', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '5l water', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '5l water', 'category': 'Jewellery', 'label': 0.0},
#  {'query': '5l water', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '5l water', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '5l water', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '5l water', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '5l water', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '5li', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '5li', 'category': 'Makeup & Beauty', 'label': 1.0},
#  {'query': '5li', 'category': 'Cleaning Essentials', 'label': 1.0},
#  {'query': '5li', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5li', 'category': 'Jewellery', 'label': 1.0},
#  {'query': '5li', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '5li', 'category': 'Kitchen & Dining', 'label': 1.0},
#  {'query': '5li', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '5li', 'category': 'Cold Drinks & Juices', 'label': 1.0},
#  {'query': '5li', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '5li', 'category': 'Breakfast & Sauces', 'label': 1.0},
#  {'query': '5li', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '5li', 'category': 'Grooming Essentials', 'label': 0.0},
#  {'query': '5li', 'category': 'Ice Creams & More', 'label': 0.0},
#  {'query': '5li', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '5li', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '5li', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '5li', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '5li', 'category': 'Munchies', 'label': 0.0},
#  {'query': '5li', 'category': 'Fragrances & Grooming', 'label': 0.0},
#  {'query': '5li', 'category': 'Electronics & Appliances', 'label': 0.0},
#  {'query': '5li', 'category': 'Packaged Food', 'label': 0.0},
#  {'query': '5li', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '5li', 'category': 'Fruits  & Vegetables', 'label': 0.0},
#  {'query': '5li', 'category': 'Baby Care', 'label': 0.0},
#  {'query': '5li',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '5li', 'category': 'Pet Care', 'label': 0.0},
#  {'query': '5li', 'category': 'Stationery & Crafts', 'label': 0.0},
#  {'query': '5li', 'category': 'Tea, Coffee & More', 'label': 0.0},
#  {'query': '5li', 'category': 'Skincare', 'label': 0.0},
#  {'query': '5li', 'category': 'Sweet Cravings', 'label': 0.0},
#  {'query': '5li', 'category': 'Masala, Dry Fruits & More', 'label': 0.0},
#  {'query': '5li', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '5li', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '5li', 'category': 'Sexual Wellness', 'label': 0.0},
#  {'query': '5li', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '5li oil', 'category': 'Atta, Rice, Oil & Dals', 'label': 1.0},
#  {'query': '5li oil', 'category': 'Zepto Cafe', 'label': 1.0},
#  {'query': '5li oil', 'category': 'Paan Corner', 'label': 0.0},
#  {'query': '5li oil', 'category': 'Meats, Fish & Eggs', 'label': 0.0},
#  {'query': '5li oil', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '5li oil', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '5rs biscuit', 'category': 'Biscuits', 'label': 1.0},
#  {'query': '5rs biscuit', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '5rs biscuit', 'category': 'Toys & Sports', 'label': 0.0},
#  {'query': '6 month baby toy', 'category': 'Toys & Sports', 'label': 1.0},
#  {'query': '6 month baby toy', 'category': 'Baby Care', 'label': 1.0},
#  {'query': '6 month baby toy', 'category': 'Home Needs', 'label': 1.0},
#  {'query': '6 month baby toy', 'category': 'Zepto Cafe', 'label': 0.0},
#  {'query': '6 month baby toy', 'category': 'Kitchen & Dining', 'label': 0.0},
#  {'query': '6 month baby toy',
#   'category': 'Dairy, Bread & Eggs',
#   'label': 0.0},
#  {'query': '6 month baby toy',
#   'category': 'Apparel & Lifestyle',
#   'label': 0.0},
#  {'query': '6 month baby toy',
#   'category': 'Grooming Essentials',
#   'label': 0.0},
#  {'query': '6 month baby toy', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '6 subject note book',
#   'category': 'Stationery & Books',
#   'label': 1.0},
#  {'query': '6 subject note book',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '6 subject note book', 'category': 'Frozen Food', 'label': 0.0},
#  {'query': '6 subject notebook',
#   'category': 'Stationery & Books',
#   'label': 1.0},
#  {'query': '6 subject notebook', 'category': 'Home Needs', 'label': 0.0},
#  {'query': '6 subject notebook',
#   'category': 'Electronics & Appliances',
#   'label': 0.0},
#  {'query': '6b pencil', 'category': 'Stationery & Books', 'label': 1.0},
#  {'query': '6b pencil', 'category': 'Feminine Hygiene', 'label': 0.0},
#  {'query': '6b pencil', 'category': 'Bath & Body', 'label': 0.0},
#  {'query': '6eggs', 'category': 'Dairy, Bread & Eggs', 'label': 1.0},
#  {'query': '6eggs', 'category': 'Zepto Cafe', 'label': 0.0},
#  {'query': '6eggs', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '6rs', 'category': 'Fruits & Vegetables', 'label': 1.0},
#  {'query': '6rs', 'category': 'Pharma & Wellness', 'label': 1.0},
#  {'query': '6rs', 'category': 'Biscuits', 'label': 0.0},
#  {'query': '6rs', 'category': 'Makeup & Beauty', 'label': 0.0},
#  {'query': '6rs', 'category': 'Dairy, Bread & Eggs', 'label': 0.0},
#  {'query': '6rs',
#   'category': 'Fragrances & Grooming Essentials',
#   'label': 0.0},
#  {'query': '7 diamonds', 'category': 'Toys & Sports', 'label': 1.0},
#  {'query': '7 diamonds', 'category': 'Munchies', 'label': 1.0},
#  {'query': '7 diamonds', 'category': 'Hair Care', 'label': 0.0},
#  {'query': '7 diamonds',
#   'category': 'Masala, Dry Fruits & More',
#   'label': 0.0},
#  ...]

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# useless

# %%
from datasets import Dataset
from transformers import AutoTokenizer

# Load tokenizer
model_name = "sentence-transformers/all-mpnet-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Your list of L1 pairs (output from make_pair_samples)
# Example:
# l1_pairs = [{'query': 'atta maggi', 'category': 'Packaged Food', 'label': 1.0}, ...]

def tokenize_example(example):
    return tokenizer(
        example['query'],
        example['category'],
        truncation=True,
        padding='max_length',
        max_length=128
    )

hf_dataset = Dataset.from_list(l1_samples)
hf_dataset = hf_dataset.map(tokenize_example, batched=False)
# Out:
# Map:   0%|          | 0/66825 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer
from peft import get_peft_model, LoraConfig, TaskType

# %%
# Load base model
base_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Apply LoRA
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q", "v"],  # adjust depending on the architecture
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.SEQ_CLS
)

model = get_peft_model(base_model, lora_config)
# Out:
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/all-mpnet-base-v2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./l1-lora-checkpoints",
    per_device_train_batch_size=32,
    learning_rate=2e-4,
    num_train_epochs=3,
    eval_strategy="no",
    save_strategy="epoch",
    logging_dir="./logs",
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=hf_dataset,
    tokenizer=tokenizer
)

trainer.train()
# Out:
# <ipython-input-18-0175e2b6f060>:12: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-0175e2b6f060> in <cell line: 0>()
#      17 )
#      18
# ---> 19 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243                 hf_hub_utils.enable_progress_bars()
#    2244         else:
# -> 2245             return inner_training_loop(
#    2246                 args=args,
#    2247                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2558                     )
#    2559                     with context():
# -> 2560                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2561
#    2562                     if (
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in training_step(self, model, inputs, num_items_in_batch)
#    3734
#    3735         with self.compute_loss_context_manager():
# -> 3736             loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3737
#    3738         del inputs
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3799                 loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3800             inputs = {**inputs, **loss_kwargs}
# -> 3801         outputs = model(**inputs)
#    3802         # Save past state if it exists
#    3803         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1519                 if peft_config.peft_type == PeftType.POLY:
#    1520                     kwargs["task_ids"] = task_ids
# -> 1521                 return self.base_model(
#    1522                     input_ids=input_ids,
#    1523                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py in forward(self, *args, **kwargs)
#     195
#     196     def forward(self, *args: Any, **kwargs: Any):
# --> 197         return self.model.forward(*args, **kwargs)
#     198
#     199     def _pre_injection_hook(self, model: nn.Module, config: PeftConfig, adapter_name: str) -> None:
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     749             elif self.config.problem_type == "multi_label_classification":
#     750                 loss_fct = BCEWithLogitsLoss()
# --> 751                 loss = loss_fct(logits, labels)
#     752         if not return_dict:
#     753             output = (logits,) + outputs[2:]
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     819
#     820     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 821         return F.binary_cross_entropy_with_logits(
#     822             input,
#     823             target,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3637
#    3638     if not (target.size() == input.size()):
# -> 3639         raise ValueError(
#    3640             f"Target size ({target.size()}) must be the same as input size ({input.size()})"
#    3641         )
#
# ValueError: Target size (torch.Size([32])) must be the same as input size (torch.Size([32, 2]))

# %%
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model, TaskType
import torch

# Load tokenizer
model_name = "sentence-transformers/all-mpnet-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Assuming l1_samples is already defined
# Example: l1_samples = [{'query': '0 calorie drink', 'category': 'Cold Drinks & Juices', 'label': 1.0}, ...]

def tokenize_example(example):
    tokenized = tokenizer(
        example['query'],
        example['category'],
        truncation=True,
        padding='max_length',
        max_length=128
    )

    # Add the label to the tokenized output
    tokenized['labels'] = int(example['label'])  # Convert float to int for binary classification
    return tokenized

# Create dataset
hf_dataset = Dataset.from_list(l1_samples)
hf_dataset = hf_dataset.map(tokenize_example, batched=False)
# Out:
# Map:   0%|          | 0/66825 [00:00<?, ? examples/s]

# %%
# Load base model
base_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Apply LoRA
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q", "v"],  # adjust depending on the architecture
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.SEQ_CLS
)

model = get_peft_model(base_model, lora_config)

# Create training arguments with corrected parameter name
training_args = TrainingArguments(
    output_dir="./l1-lora-checkpoints",
    per_device_train_batch_size=32,
    learning_rate=2e-4,
    num_train_epochs=3,
    eval_strategy="no",  # Corrected from eval_strategy
    save_strategy="epoch",
    logging_dir="./logs",
    report_to="none"
)
# Out:
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/all-mpnet-base-v2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits

        # For binary classification with num_labels=2
        loss_fct = torch.nn.CrossEntropyLoss()
        loss = loss_fct(logits.view(-1, 2), labels.view(-1))

        return (loss, outputs) if return_outputs else loss

# %%
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=hf_dataset
)

# Start training
trainer.train()

# Save the fine-tuned model
model.save_pretrained("./l1-lora-fine-tuned")
# Out:
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-5b777d72356a> in <cell line: 0>()
#       6
#       7 # Start training
# ----> 8 trainer.train()
#       9
#      10 # Save the fine-tuned model
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243                 hf_hub_utils.enable_progress_bars()
#    2244         else:
# -> 2245             return inner_training_loop(
#    2246                 args=args,
#    2247                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2558                     )
#    2559                     with context():
# -> 2560                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2561
#    2562                     if (
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in training_step(self, model, inputs, num_items_in_batch)
#    3734
#    3735         with self.compute_loss_context_manager():
# -> 3736             loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3737
#    3738         del inputs
#
# TypeError: CustomTrainer.compute_loss() got an unexpected keyword argument 'num_items_in_batch'

# %% [markdown]
# useful

# %%
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model, TaskType
import torch

# Load tokenizer
model_name = "sentence-transformers/all-mpnet-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Assuming l1_samples is already defined
# Example: l1_samples = [{'query': '0 calorie drink', 'category': 'Cold Drinks & Juices', 'label': 1.0}, ...]

def tokenize_example(example):
    tokenized = tokenizer(
        example['query'],
        example['category'],
        truncation=True,
        padding='max_length',
        max_length=128
    )

    # Add the label to the tokenized output
    tokenized['labels'] = int(example['label'])  # Convert float to int for binary classification
    return tokenized

# Create dataset
hf_dataset = Dataset.from_list(l1_samples)
hf_dataset = hf_dataset.map(tokenize_example, batched=False)

# %%
# Load base model
base_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Apply LoRA
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q", "v"],  # adjust depending on the architecture
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.SEQ_CLS
)

model = get_peft_model(base_model, lora_config)

# Create training arguments with corrected parameter name
training_args = TrainingArguments(
    output_dir="./l1-lora-checkpoints",
    per_device_train_batch_size=32,
    learning_rate=2e-4,
    num_train_epochs=3,
    eval_strategy="no",  # Corrected from eval_strategy
    save_strategy="epoch",
    logging_dir="./logs",
    report_to="none"
)

# Fixed CustomTrainer - added support for num_items_in_batch parameter
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits

        # For binary classification with num_labels=2
        loss_fct = torch.nn.CrossEntropyLoss()
        loss = loss_fct(logits.view(-1, 2), labels.view(-1))

        return (loss, outputs) if return_outputs else loss

# Use the custom trainer
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=hf_dataset
)

# Start training
trainer.train()

# Save the fine-tuned model
model.save_pretrained("/content/drive/MyDrive/Zepto IDC Query Classification/l1-lora-fine-tuned")
# Out:
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/all-mpnet-base-v2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='6267' max='6267' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6267/6267 48:31, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.518700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.450500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.428400</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.419100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.416100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.404100</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.396200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.385700</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.382100</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.381800</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.373600</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.377500</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from transformers import AutoTokenizer, AutoModel

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from peft import PeftModel

# Step 1: Load base model and tokenizer
model_name = "sentence-transformers/all-mpnet-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
base_model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Step 2: Load LoRA adapter into the base model
lora_model_path = "/content/drive/MyDrive/Zepto IDC Query Classification/l1-lora-fine-tuned"
model = PeftModel.from_pretrained(base_model, lora_model_path)
model.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/all-mpnet-base-v2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PeftModelForSequenceClassification(
#   (base_model): LoraModel(
#     (model): MPNetForSequenceClassification(
#       (mpnet): MPNetModel(
#         (embeddings): MPNetEmbeddings(
#           (word_embeddings): Embedding(30527, 768, padding_idx=1)
#           (position_embeddings): Embedding(514, 768, padding_idx=1)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder): MPNetEncoder(
#           (layer): ModuleList(
#             (0-11): 12 x MPNetLayer(
#               (attention): MPNetAttention(
#                 (attn): MPNetSelfAttention(
#                   (q): lora.Linear(
#                     (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (k): Linear(in_features=768, out_features=768, bias=True)
#                   (v): lora.Linear(
#                     (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (o): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (intermediate): MPNetIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): MPNetOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#           (relative_attention_bias): Embedding(32, 12)
#         )
#       )
#       (classifier): ModulesToSaveWrapper(
#         (original_module): MPNetClassificationHead(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out_proj): Linear(in_features=768, out_features=2, bias=True)
#         )
#         (modules_to_save): ModuleDict(
#           (default): MPNetClassificationHead(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (out_proj): Linear(in_features=768, out_features=2, bias=True)
#           )
#         )
#       )
#     )
#   )
# )

# %%
import pandas as pd

# %%
catalog_df = pd.read_csv("/content/drive/MyDrive/Zepto IDC Query Classification/Zepto Data Challenge_ Intent prediction - catalog.csv")
catalog_df = catalog_df.drop_duplicates(subset=["product_variant_id"])

# %%
l1_df = catalog_df[['product_name', 'l1_name']].dropna().drop_duplicates()

# Combine product and category context
l1_inputs = [f"L1: {product} | {cat}" for product, cat in zip(l1_df['product_name'], l1_df['l1_name'])]

# %%
l1_categories
# Out:
# ['Baby Care',
#  'Kitchen & Dining',
#  'Frozen Food',
#  'Stationery & Books',
#  'Fruits & Vegetables',
#  'Cleaning Essentials',
#  'Dairy, Bread & Eggs',
#  'Packaged Food',
#  'Munchies',
#  'Meats, Fish & Eggs',
#  'Zepto Cafe',
#  'Biscuits',
#  'Bath & Body',
#  'Tea, Coffee & More',
#  'Fragrances & Grooming',
#  'Cold Drinks & Juices',
#  'Paan Corner']

# %%
l1_inputs
# Out:
# ['L1: himalaya baby lotion | Baby Care',
#  "L1: johnson's baby lotion | Baby Care",
#  'L1: cetaphil baby daily lotion | Baby Care',
#  'L1: sebamed baby body lotion, for all skin types | Baby Care',
#  'L1: himalaya baby lotion with pure cow ghee & ph 5.5 | Baby Care',
#  'L1: parachute advansed baby lotion for new born babies virgin coconut oil & coconut milk | Baby Care',
#  "L1: johnson's baby lotion bmr ecom | Baby Care",
#  'L1: tedibar family atogla lotion for baby | Baby Care',
#  'L1: avn baby daily moisture lotion | Baby Care',
#  'L1: vesta homes round wooden 360 degree rotating cake stand, dessert platter|dia-10.5 inch, h- 3 inch | Kitchen & Dining',
#  'L1: meatigo frozen chicken boneless breast | Frozen Food',
#  'L1: meatzza fresh boneless chicken breast | Frozen Food',
#  'L1: sneha supercool fz breast boneless | Frozen Food',
#  'L1: meatigo everyday herb & lime chicken breast (frozen) | Frozen Food',
#  'L1: measuring spoon | Kitchen & Dining',
#  'L1: anjali measuring spoon | Kitchen & Dining',
#  'L1: camel painting kit | Stationery & Books',
#  'L1: chrome 3 pcs white medium charcoal art drawing pencils set for dark tinted paper | Stationery & Books',
#  'L1: chrome calligraphy 4 nib pen set (silver) | Stationery & Books',
#  'L1: chrome 5 piece embossing acrylic dotting tool set | Stationery & Books',
#  'L1: tomato sauce bottle 150 ml | 2 pcs set white | Kitchen & Dining',
#  'L1: plain sauce bottle 500 ml yellow | 2pcs set | Kitchen & Dining',
#  'L1: godrej yummiez chicken breast boneless | Frozen Food',
#  'L1: deli chic chicken whole tandori freshly frozen | Frozen Food',
#  'L1: beetroot | Fruits & Vegetables',
#  'L1: beetroot ooty | Fruits & Vegetables',
#  'L1: beetroot 250 g combo | Fruits & Vegetables',
#  'L1: beetroot 500 g combo | Fruits & Vegetables',
#  'L1: organic beetroot | Fruits & Vegetables',
#  'L1: broccoli | Fruits & Vegetables',
#  'L1: godrej yummiez chicken breakfast salami | Frozen Food',
#  'L1: godrej yummiez chicken pepper & herb salami | Frozen Food',
#  'L1: prasuma frozen chicken pepperoni salami | Frozen Food',
#  'L1: prasuma chicken chilli salami | Frozen Food',
#  'L1: savlon surface disinfectant sanitizer spray, germ protection on hard & soft surfaces | Cleaning Essentials',
#  'L1: dettol liquid disinfectant-floor cleaner, surface disinfection, personal hygiene-fresh lime | Cleaning Essentials',
#  'L1: dettol multi-surface disinfectant sanitizer spray orchard bloom | Cleaning Essentials',
#  'L1: dettol liquid disinfectant -floor cleaner, surface disinfection, personal hygiene - lime fresh | Cleaning Essentials',
#  'L1: dettol liquid disinfectant - floor cleaner, surface disinfection, personal hygiene - lavender | Cleaning Essentials',
#  'L1: dettol liquid disinfectant-floor cleaner, surface disinfection, personal hygiene-menthol cool | Cleaning Essentials',
#  'L1: britannia fruit bun | Dairy, Bread & Eggs',
#  'L1: english oven fruit bun | Dairy, Bread & Eggs',
#  'L1: ocean finline water glass (280ml, 6pcs) | Kitchen & Dining',
#  'L1: reusable party glass (set of 6) | Kitchen & Dining',
#  'L1: bay6 drinking glass set 250 ml - (6pc) | Kitchen & Dining',
#  'L1: ocean pop glass jar set with glass lid (325ml, 2pcs) | Kitchen & Dining',
#  'L1: ocean ivory water glass set (370 ml) | Kitchen & Dining',
#  'L1: roxx tulip stem 2 pcs glass 300 ml | Kitchen & Dining',
#  'L1: ocean lumi borosilicate water glass (300ml, 6pcs) | Kitchen & Dining',
#  'L1: ocean san marino water glass (350ml, 6pcs) | Kitchen & Dining',
#  'L1: sanjeev kapoor amsterdam high borosilicate square glass 280 ml - set of 6 pcs | Kitchen & Dining',
#  'L1: skb1517 dubai juice glass 230 ml | set of 6 piece | Kitchen & Dining',
#  'L1: ocean plaza water glass (320ml, 6pcs) | Kitchen & Dining',
#  'L1: ocean unity juice glass (255ml, 6pcs) | Kitchen & Dining',
#  'L1: oggn copper glass | Kitchen & Dining',
#  'L1: agaro elegant octagonal glass 200ml set of 6 | Kitchen & Dining',
#  'L1: ocean connexion water glass (350ml, 6pcs) | Kitchen & Dining',
#  'L1: ocean tango juice glass (255ml) | Kitchen & Dining',
#  'L1: borosil vision transparent drinking glass set (295 ml) borosilicate glass tumblers | Kitchen & Dining',
#  'L1: agaro elite borosilicate glass tumbler, serves water, cold drinks, juice, milk, pack of 6, 300 ml | Kitchen & Dining',
#  'L1: ocean unity water glass set (290 ml) | Kitchen & Dining',
#  'L1: all time picnic reusable glass set of 4 for party, gettogether, (500 ml x 4)(assorted color) | Kitchen & Dining',
#  'L1: ocean ivory water glass platinum band (370ml, 6pcs) | Kitchen & Dining',
#  'L1: skb1519 dubai water glass 290 ml | set of 6 piece | Kitchen & Dining',
#  'L1: sanjeev kapoor costa borosilicate round glass 220 ml - set of 6 pcs | Kitchen & Dining',
#  'L1: borosil vision transparent drinking glass set (350 ml) | borosilicate glass | tumblers, pack of 1 (6 pieces) | Kitchen & Dining',
#  'L1: kavi the poetry-art project absolut sipper | Kitchen & Dining',
#  'L1: nestasia transparent tall glass tumblers - set of 6 (300ml) | Kitchen & Dining',
#  'L1: treo by milton set vector 300 ml 6pc | Kitchen & Dining',
#  'L1: sanjeev kapoor oslo water glass 290 ml - set of 6 pcs | Kitchen & Dining',
#  'L1: skb2016 iceland long drink glass 380 ml | set of 6 piece | Kitchen & Dining',
#  'L1: roxx octave hb tumbler glass - 300 ml | pack of 6 | Kitchen & Dining',
#  'L1: old monk face glasses 300 ml (set of 2) | Kitchen & Dining',
#  'L1: sanjeev kapoor berlin high borosilicate square glass 330 ml - set of 6 pcs | Kitchen & Dining',
#  'L1: signoraware ilusion glass regular (set/6) 1901clear | Kitchen & Dining',
#  'L1: organic watermelon | Fruits & Vegetables',
#  'L1: gourmet garden organic watermelon | Fruits & Vegetables',
#  'L1: double horse rice palada payasam mix | Packaged Food',
#  'L1: bambino vermicelli kheer payasam dessert mix | Packaged Food',
#  'L1: godrej yummiez chicken punjabi tikka | Frozen Food',
#  'L1: kafan | premchand | hindi | Stationery & Books',
#  'L1: premchand - novels |hindi | |set of 2 books | - nirmala and pratigya | Stationery & Books',
#  'L1: 108 tenali raman stories |illustrated | |hindi | - bedtime stories - story book for kids | Stationery & Books',
#  'L1: godan - premchand | Stationery & Books',
#  'L1: tenali raman |hindi | |illustrated | - story book for kids - hindi short stories for children | Stationery & Books',
#  'L1: 41 anmol kahaniya - premchand - hindi short stories for kids | Stationery & Books',
#  'L1: the power of your subconscious mind (tamil) | Stationery & Books',
#  'L1: the power of a positive attitude (hindi) | Stationery & Books',
#  'L1: the power of subconscious mind (marathi) | Stationery & Books',
#  'L1: best of premchand | set of 5 hindi books - godan | gaban | nirmala | kafan | karmbhumi | Stationery & Books',
#  'L1: mantra vigyan se aage (hindi) | Stationery & Books',
#  'L1: think and grow rich (hindi) | Stationery & Books',
#  'L1: balaji aloo sev | Munchies',
#  'L1: balaji ratlami sev | Munchies',
#  "L1: haldiram's ratlami sev | Munchies",
#  'L1: namaskaram nylon sev - bhel sev | Munchies',
#  'L1: yellow diamond aloo bhujiya | Munchies',
#  'L1: garden nylon sev | Munchies',
#  "L1: chheda's nylon sev | Munchies",
#  "L1: haldiram's long sev | Munchies",
#  'L1: charliee sev puri | Munchies',
#  'L1: yellow diamond bhujiya sev | Munchies',
#  'L1: lets try sev bhujia | Munchies',
#  'L1: strawberry | Fruits & Vegetables',
#  'L1: freshtohome turkey - curry cut (480g to 500g pack) | Meats, Fish & Eggs',
#  'L1: himalaya baby care gift pack set of 7 | Baby Care',
#  'L1: himalaya baby basket gift pack, violet combo | Baby Care',
#  'L1: superbottoms newborn baby gift set (0-3months) | clothing gift set pack of 11 | Baby Care',
#  'L1: mee mee bpa free baby rattles set gifts for new born girls boys (3 toys) | Baby Care',
#  "L1: johnson's baby gift set (10 products) | Baby Care",
#  'L1: superbottoms pure love gift set for newborn (0-6 months) boys & girls | Baby Care',
#  "L1: little's 3 in 1 infant classic gift pack i activity & learning toys for babies i multicolour | Baby Care",
#  'L1: mee mee soft cotton newborn clothing hamper baby gift set | blue | Baby Care',
#  'L1: chicco baby moments baby caring set blue | Baby Care',
#  'L1: superbottoms pure love gift set for newborn (0-6 months) baby boys & girls | Baby Care',
#  "L1: johnson's baby gift set (11 products) | Baby Care",
#  'L1: superbottoms basic langot upto 5 kg babies, pure cotton langot | Baby Care',
#  'L1: funskool giggles gift set mini | Baby Care',
#  'L1: chicco baby moments baby caring set purple | Baby Care',
#  'L1: navneet youva primed canvas board for acrylic and oil colour painting size 8 x 10 inch | Stationery & Books',
#  'L1: navneet youva primed canvas board for acrylic and oil colour painting 6x6 inch | Stationery & Books',
#  'L1: navneet youva primed canvas board for acrylic and oil colour painting size 10 x 12 inch | Stationery & Books',
#  'L1: fevicryl fine art canvas board | Stationery & Books',
#  'L1: navneet youva primed canvas board for acrylic and oil colour painting size 12 x 16 inch | Stationery & Books',
#  'L1: deli chic chicken liver | Frozen Food',
#  'L1: leather multipurpose 20 sleeve file folder for certificates and documents | Stationery & Books',
#  'L1: pockets folder/ file with 20 leaves | Stationery & Books',
#  'L1: slide grip binder files | Stationery & Books',
#  'L1: saya assorted report file classic - a4 clear | Stationery & Books',
#  'L1: worldone slide grip binder file (10mm sliding bar) - assorted | Stationery & Books',
#  'L1: worldone ring binder file | Stationery & Books',
#  'L1: rasbhari | Fruits & Vegetables',
#  'L1: roquette / arugula | Fruits & Vegetables',
#  "L1: hellmann's paneer tikka sandwich | Zepto Cafe",
#  'L1: chicken shawarma sandwich | Zepto Cafe',
#  'L1: chicken peri peri sandwich | Zepto Cafe',
#  'L1: bombay aloo tikki sandwich | Zepto Cafe',
#  'L1: paneer tikka sandwich | Zepto Cafe',
#  'L1: avocado sandwich | Zepto Cafe',
#  'L1: cottage cheese focaccia sandwich | Zepto Cafe',
#  'L1: sneakare rpl 100ml | Cleaning Essentials',
#  'L1: amul taaza homogenised toned milk (tetra pack) | Dairy, Bread & Eggs',
#  'L1: amul lactose free milk (tetra pack) | Dairy, Bread & Eggs',
#  'L1: nandini goodlife toned uht milk (fino pouch) | Dairy, Bread & Eggs',
#  'L1: amul moti - homogenised toned milk (pouch 90 days shelf life) | Dairy, Bread & Eggs',
#  'L1: nandini goodlife milk uht (pouch brik) | Dairy, Bread & Eggs',
#  'L1: nandini goodlife toned milk uht (tetra pack brick) | Dairy, Bread & Eggs',
#  'L1: nandini good life toned uht milk (fino pouch) | Dairy, Bread & Eggs',
#  'L1: amul gold homogenised standardised milk (tetra pack) | Dairy, Bread & Eggs',
#  'L1: amul slim trim skimmed milk (tetra pack) | Dairy, Bread & Eggs',
#  'L1: arokya standardized fresh milk (pouch) | Dairy, Bread & Eggs',
#  'L1: nandini goodlife slim skimmed milk uht (tetra pack) | Dairy, Bread & Eggs',
#  'L1: dodla long life toned milk- uht | Dairy, Bread & Eggs',
#  'L1: nandini goodlife slim skimmed milk uht (tetra pack brik) | Dairy, Bread & Eggs',
#  'L1: godrej jersey standardized milk | Dairy, Bread & Eggs',
#  'L1: heritage farm fresh toned tetra pack milk | Dairy, Bread & Eggs',
#  'L1: akshayakalpa organic cow milk - uht | Dairy, Bread & Eggs',
#  'L1: keventer metro rich milk | Dairy, Bread & Eggs',
#  'L1: amul taaza homogenised toned milk (tetra pack) 1 l combo | Dairy, Bread & Eggs',
#  'L1: humpy farms a2 uht cow milk (pouch) | Dairy, Bread & Eggs',
#  'L1: nandini goodlife gold uht milk (tetra pack) | Dairy, Bread & Eggs',
#  'L1: vijaya homogenised toned milk | Dairy, Bread & Eggs',
#  'L1: nandini goodlife toned milk uht (tetra pack brick) 1 l combo | Dairy, Bread & Eggs',
#  'L1: muralya pet bottle regular milk | Dairy, Bread & Eggs',
#  'L1: amul gold homogenised standardised milk (tetra pack) 1 l combo | Dairy, Bread & Eggs',
#  'L1: baby sebamed lip balm | soft baby lips | with shea butter, jojoba oil & beeswax | Baby Care',
#  'L1: doms coloured chalk | Stationery & Books',
#  'L1: amul cheese spread yummy plain | Dairy, Bread & Eggs',
#  'L1: dlecta cheese spread | Dairy, Bread & Eggs',
#  'L1: amul cheese spread spicy garlic | Dairy, Bread & Eggs',
#  'L1: go cheese spread plain | Dairy, Bread & Eggs',
#  'L1: go pizza cheese | Dairy, Bread & Eggs',
#  'L1: amul cheese spread - pepper | Dairy, Bread & Eggs',
#  'L1: nandini cheese spread- plain | Dairy, Bread & Eggs',
#  'L1: britannia the laughing cow cheese spread- classic tub | Dairy, Bread & Eggs',
#  'L1: amul cheese spread creamy | Dairy, Bread & Eggs',
#  'L1: colocasia leaves (arvi patta) | Fruits & Vegetables',
#  'L1: colocasia leaves (arvi patta) 5 pc combo | Fruits & Vegetables',
#  'L1: jamun cooler | Zepto Cafe',
#  'L1: weikfield custard powder vanilla flavour carton | Packaged Food',
#  'L1: pillsbury vanilla custard powder | Packaged Food',
#  'L1: weikfield custard powder butterscotch flavoured carton | Packaged Food',
#  'L1: weikfield custard ready to eat - vanilla | Packaged Food',
#  'L1: britannia 50-50 maska chaska biscuits | Biscuits',
#  'L1: malkist cheese crunchy layered crackers | Biscuits',
#  'L1: malkist double chocolatey crunchy layered crackers | Biscuits',
#  'L1: sunfeast all rounder, thin, light & crunchy potato biscuit with chatpata masala flavour | Biscuits',
#  'L1: britannia 50-50 maska chaska biscuit 105 g combo | Biscuits',
#  'L1: malkist cheese crunchy layered crackers 144 g combo | Biscuits',
#  'L1: britannia 50-50 potazos masti masala spicy flavoured crisps, chips and biscuit combination | Biscuits',
#  'L1: malkist cappuccino flavoured cracker biscuits | Biscuits',
#  'L1: sunfeast all rounder, thin, light & crunchy potato biscuit with chatpata masala flavour 70 g combo | Biscuits',
#  'L1: dukes nibbles - jeera crackers | Biscuits',
#  'L1: unibic snapper indie spice | Biscuits',
#  "L1: orion o'rice cracker - baked korean snack | Biscuits",
#  'L1: unibic snapper cream & onion | Biscuits',
#  'L1: britannia biscafe | refreshing super thin coffee cracker | Biscuits',
#  'L1: gits dessert mix - jalebi with maker | Packaged Food',
#  'L1: gits instant kesar kulfi dessert mix | Packaged Food',
#  'L1: britannia marie gold biscuit | Biscuits',
#  'L1: britannia vita marie gold biscuits, zero transfat, vitamin enriched biscuits | Biscuits',
#  'L1: parle marie biscuit | Biscuits',
#  'L1: britannia marie gold biscuit 117 g combo | Biscuits',
#  'L1: sunfeast marie light biscuits | Biscuits',
#  'L1: britannia marie gold biscuits | Biscuits',
#  'L1: haldirams cookie heaven atta cookies | Biscuits',
#  'L1: britannia vita marie gold biscuits, zero transfat, vitamin enriched biscuits 248 g combo | Biscuits',
#  'L1: biskfarm rich marie | Biscuits',
#  'L1: britannia vita marie gold biscuits | Biscuits',
#  'L1: sweet karam coffee garlic murukku sticks | Munchies',
#  'L1: vs mani garlic ribbon murukku, no palm oil | Munchies',
#  'L1: too yumm! sour cream & onion veggie stix | munching snack | on-the-go munchies 75 g combo | Munchies',
#  "L1: rajaram's butter murukku | Munchies",
#  'L1: unibic swaadesi no palm oil butter ribbon murukku | Munchies',
#  "L1: rajaram's spicy tapioca sticks | Munchies",
#  'L1: britannia nutrichoice oats milk & almond biscuits | Biscuits',
#  'L1: britannia nutrichoice oats orange & almond biscuits | Biscuits',
#  'L1: britannia nutrichoice oats chocolate & almond biscuits | Biscuits',
#  'L1: sunfeast farmlite oats & almonds biscuits packet | Biscuits',
#  'L1: sunfeast farmlite biscuit - cookies - oats and chocolate | Biscuits',
#  'L1: britannia nutri choice oats milk almond biscuit 75 gms x 3 combo | Biscuits',
#  'L1: sunfeast farmlite biscuit - cookies - oats & raisins | Biscuits',
#  'L1: mcvitie’s hobnobs cookies , 0% maida & 38% oats | Biscuits',
#  'L1: sunfeast farmlite oats & almonds biscuits packet 150 g combo | Biscuits',
#  'L1: britannia nutrichoice oats orange & almond biscuits | 0% maida 75 g combo | Biscuits',
#  "L1: mcvitie's hobnobs crunchy chocochip cookies , 0% maida & 36% oats | Biscuits",
#  'L1: britannia nutrichoice oats chocolate & almond biscuits | 0% maida 75 g combo | Biscuits',
#  'L1: slurrp farm banana oat cookies - no maida & no refined sugar, 88 gm | Biscuits',
#  "L1: let's try oats coconut cookies | Biscuits",
#  'L1: crystal stainless steel  oil pourer/ dispenser 1000 ml | Kitchen & Dining',
#  'L1: raw jackfruit | Fruits & Vegetables',
#  'L1: stainless steel cutlery stand | Kitchen & Dining',
#  'L1: jensons ss 3 pcs kitchen tool | Kitchen & Dining',
#  'L1: jensons ss 4 pcs serving tool | Kitchen & Dining',
#  'L1: classic essentials spoon fork stainless steel cutlery set pack of 12 | Kitchen & Dining',
#  'L1: bombay kookware stainless steel cooking & serving - karchi pack of 5 | Kitchen & Dining',
#  'L1: ganesh stainless steel - matt finish pakkad - kitchen pincers - sansi - regular kitchen tool -8mm | Kitchen & Dining',
#  'L1: bombay kookware stainless steel sj thali set (pack of 5) | Kitchen & Dining',
#  'L1: bay6 steel butter dish with knife - 500 ml | Kitchen & Dining',
#  'L1: stainless steel serving spoon set for dining (set of 4 serving spoons) | Kitchen & Dining',
#  'L1: kohinoor ready to cook hyderabadi biryani kit | Packaged Food',
#  'L1: kohinoor lucknowi biryani kit kohinoor authentic basmati biryani kit | Packaged Food',
#  'L1: cookd wedding bhai biryani kit | Packaged Food',
#  "L1: l'oreal paris hyaluron moisture 72h hydra filling night cream | Bath & Body",
#  'L1: ayuvya imfresh body deodorant cream (honey oudh) | Bath & Body',
#  'L1: roxx bullet jug 1.1 l - new | Kitchen & Dining',
#  'L1: agaro elite borosilicate water jug 1.8ltr, stainless steel air tight lid, carafes | Kitchen & Dining',
#  'L1: femora crystal clear glass jug with handle 1.5l borosilicate glass | Kitchen & Dining',
#  'L1: agaro elegant glass jug with lid, 1.1l carafes jug pitcher | Kitchen & Dining',
#  'L1: all time plastic measure & pour jug 1000 ml, transparent | Kitchen & Dining',
#  'L1: sanjeev kapoor quadro fridge jug (1.1 l) | Kitchen & Dining',
#  'L1: signoraware ocean jug, 1.65 litres, 405white | Kitchen & Dining',
#  'L1: signoraware saffron borosilicate glass jug with bamboo lid 1000ml, 1460clear | Kitchen & Dining',
#  'L1: princeware blue sea water jug 2500 ml- pink | Kitchen & Dining',
#  'L1: princeware blue sea water jug 2500 ml- blue | Kitchen & Dining',
#  'L1: femora borosilicate glass water jug with handle juice beverage carafe 1.8 ltr (bpa free) | Kitchen & Dining',
#  'L1: tata agni tea | Tea, Coffee & More',
#  'L1: tata tea premium tea | Tea, Coffee & More',
#  'L1: red label tea | Tea, Coffee & More',
#  'L1: red label natural care tea | with 5 ayurvedic ingredients | Tea, Coffee & More',
#  'L1: wagh bakri premium leaf tea | Tea, Coffee & More',
#  'L1: society leaf tea | Tea, Coffee & More',
#  'L1: tata tea gold | Tea, Coffee & More',
#  'L1: taj mahal tea | Tea, Coffee & More',
#  'L1: tata tea gold care | Tea, Coffee & More',
#  'L1: wagh bakri premium spiced tea | Tea, Coffee & More',
#  'L1: marvel premium tea | Tea, Coffee & More',
#  'L1: tata agni strong leaf 10% extra strong leaves | Tea, Coffee & More',
#  'L1: tata premium tea | Tea, Coffee & More',
#  'L1: tata tea premium, desh ki chai, black tea | Tea, Coffee & More',
#  'L1: taj mahal tea 1 kg- rich and flavourful chai - premium leaf tea | Tea, Coffee & More',
#  'L1: society masala flavour tea | Tea, Coffee & More',
#  'L1: chaayos adrak elaichi tea ginger & cardamom | Tea, Coffee & More',
#  'L1: girnar pure & fresh royal cup tea | Tea, Coffee & More',
#  'L1: chaayos masala tea - premium chai patti with 100% natural spices | Tea, Coffee & More',
#  'L1: daily good kadak tea - strong | Tea, Coffee & More',
#  'L1: mccain chilli garlic potato bites nuggets | Frozen Food',
#  'L1: mccain chilli cheesy nuggets | Frozen Food',
#  'L1: godrej yummiez cheese corn nuggets | Frozen Food',
#  'L1: itc master chef cheesy corn triangles veg frozen snack ready to cook | Frozen Food',
#  'L1: luvlap baby safety furniture locks | Baby Care',
#  'L1: varmora multi utility plastic storage boxes - set of 3 | assorted | Kitchen & Dining',
#  'L1: bay6 stainless steel tong | Kitchen & Dining',
#  'L1: anjali s.s chappati tong | Kitchen & Dining',
#  'L1: khatana doctor pakad | 1 inch | Kitchen & Dining',
#  'L1: vinayak stainless steel tong/pakad (1 unit) | Kitchen & Dining',
#  'L1: kuber industries stainless steel pakkad | kitchen tong (silver) (kubmart010370) | Kitchen & Dining',
#  'L1: anjali pakkad | Kitchen & Dining',
#  'L1: happy kitchen stainless steel tong/pakad (metallic) | Kitchen & Dining',
#  'L1: ariel matic detergent powder top load | for washing machines | Cleaning Essentials',
#  'L1: surf excel matic top load detergent powder | Cleaning Essentials',
#  'L1: puramate coloured balls | cake | muffin decoration | Packaged Food',
#  'L1: lets try crunchy party mix | Munchies',
#  'L1: farmley party mix snacks mix dry fruits nuts & seeds | Munchies',
#  'L1: bazana party trail mix | Munchies',
#  'L1: mom daily health mix | Munchies',
#  'L1: wembley baby bath toys 3 pcs spinner toy for baby spinners for baby toddlers boys girls | Baby Care',
#  'L1: wembley swimming turtle bath toys for toddlers kids cute floating wind up on water (pack - 1) | Baby Care',
#  'L1: pillsbury cooker cake mix - choco | Packaged Food',
#  'L1: pillsbury oven cake mix - rich chocolate | Packaged Food',
#  'L1: pillsbury rich choco oven cake mix - egg free | Packaged Food',
#  'L1: betty crocker triple chocolate brownie instant cake mix powder | Packaged Food',
#  'L1: cello chiller ice box - 3 l assorted | Kitchen & Dining',
#  "L1: colgate kid's 2+ years extra soft toothbrush | Baby Care",
#  'L1: colgate kids extra soft toothbrush | Baby Care',
#  'L1: colgate kids barbie toothbrush, extra soft with tongue cleaner | Baby Care',
#  'L1: colgate kids 0-2 extra soft tooth brush | Baby Care',
#  'L1: oral-b tom & jerry kids toothbrush - extra soft bristles, easy-to-hold handle | Baby Care',
#  'L1: colgate kids (6+ years) minion toothbrush, extra soft with tongue cleaner - 1 pc & toothpaste | Baby Care',
#  'L1: colgate kids 2+ years extra soft toothbrush | Baby Care',
#  'L1: sanjeev kapoor lugano beer mug (380ml) | Kitchen & Dining',
#  'L1: sanjeev kapoor royal pilsner glass set (275 ml) | Kitchen & Dining',
#  'L1: sanjeev kapoor playboy beer mug set (380 ml) | Kitchen & Dining',
#  'L1: bay6 beer glass set - 360 ml - (2pc) | Kitchen & Dining',
#  'L1: tropical beer mug - 400 ml | Kitchen & Dining',
#  'L1: skb2790 skull head beer mug 500ml | set of 2 piece | Kitchen & Dining',
#  'L1: ocean playboy beer mug (357ml, 2pcs) | Kitchen & Dining',
#  'L1: luminarc glass beer mug - pack of 2 | Kitchen & Dining',
#  'L1: ocean munich beer mug (355ml, 2pcs) | Kitchen & Dining',
#  'L1: magnus fancy 3 steel lunch box set with stainless steel washable cover, and stylish carry bag | Kitchen & Dining',
#  'L1: asian plastoware mini meal hot lunch box- assorted | Kitchen & Dining',
#  'L1: magnus olive 3 lunch box set leak-proof steel containers for school with insulated bag (950 ml) | Kitchen & Dining',
#  'L1: asian diet meal lunch box with 3 containers assorted color | Kitchen & Dining',
#  'L1: magnus fancy 3 prime steel lunch box set with stainless steel contianers and stylish carry bag | Kitchen & Dining',
#  'L1: cello double treat lunch box with jacket (2 unit container - 300 ml, 1 unit oval container) | blue | Kitchen & Dining',
#  'L1: milton executive lunch box, 2 round containers, 280 ml each, 1 oval container, 450 ml, black | Kitchen & Dining',
#  'L1: magnus avanza 3 steel leakproof lunch box for school with klip lock lid & insulated tiffin bag | Kitchen & Dining',
#  'L1: magnus microwave eva 5 lunch box ( black ) - 3 containers, 1 small box, 1 bottle, cutlery stainless | Kitchen & Dining',
#  'L1: bombay kookware stainless steel vati | Kitchen & Dining',
#  'L1: jensons essence 2 lunch box | Kitchen & Dining',
#  'L1: veigo large - stainless steel leakproof tiffin box (630 ml) compact for outdoors navy blue | Kitchen & Dining',
#  'L1: cello double treat lunch box with jacket (2 unit container - 300 ml, 1 unit oval container) | red | Kitchen & Dining',
#  'L1: magnus olive-3 prime stainless steel lunchbox with leak-proof containers & insulated carry case | Kitchen & Dining',
#  'L1: magnus bolt dlx stainless steel lunch box with lid for school (800ml + 150ml) | Kitchen & Dining',
#  'L1: milton executive lunch box, 2 round containers, 280 ml each, 1 oval container, 450 ml, army green | Kitchen & Dining',
#  'L1: nayasa microfresh crunchy munchy tiffin assorted colour | Kitchen & Dining',
#  'L1: prettykrafts lunch bags reusable lunch bag with hook and loop closure grey and black | Kitchen & Dining',
#  'L1: jensons stainless steel quade meal 3 lunch box | Kitchen & Dining',
#  'L1: nayasa round double decker lunchbox | Kitchen & Dining',
#  'L1: veigo sandwich - stainless steel leakproof tiffin box (630 ml) compact square design - green | Kitchen & Dining',
#  'L1: ganesh oval lunch box steel with 4 side lock lid 100 ml easy to carry - assorted | Kitchen & Dining',
#  'L1: pexpo steel meal box ultra with 750 ml chromo water bottle 1 pickle box & 1 spoon 4 containers. | Kitchen & Dining',
#  'L1: milton executive lunch insulated tiffin with 3 leakproof containers, green | Kitchen & Dining',
#  'L1: veigo heatup small- microwave safe stainless steel leakproof veg box(180 ml) peach fuzz | Kitchen & Dining',
#  'L1: magnus stainless steel easy lock container - 400ml | leak-proof airtight & bpa free | Kitchen & Dining',
#  'L1: magnus vivid solid glass lunch box- vertical pouch- fixed clip-3 square glass containers-320ml each | Kitchen & Dining',
#  'L1: pexpo stainless steel lunch box with 2 leakproof air-tight round container & cover bag (black) nano | Kitchen & Dining',
#  'L1: treo by milton all fresh premier tiffin set of 8 | Kitchen & Dining',
#  'L1: jaypee wavesteel jr. stainless steel insulated lunch box for school kids ,peacock plum , 500 ml | Kitchen & Dining',
#  'L1: jensons stainless steel wonder 3 lunch box | Kitchen & Dining',
#  'L1: vinayak stainless steel lunch box (microwave safe) (3 x 280 ml, red) | Kitchen & Dining',
#  'L1: signoraware compact lunch box set, 850ml+100ml+100ml, set/3, 514turquioseblue | Kitchen & Dining',
#  'L1: magnus olive-2 stainless steel lunchbox with leak-proof containers & insulated carry case | Kitchen & Dining',
#  'L1: signoraware slim high borosilicate glass small lunch box, 600ml, 1507clear | Kitchen & Dining',
#  'L1: jensons stainless steel wonder 2 lunch box | Kitchen & Dining',
#  'L1: borosil klip-n-store lunch box with bag, set of 3 (400 ml each) microwavable, office tiffin, blue | Kitchen & Dining',
#  'L1: jensons essence 3 lunch box | Kitchen & Dining',
#  'L1: milton school time plastic lunch box(assorted, pack of 1) | Kitchen & Dining',
#  'L1: varmora fresh bite kids lunch box - pista green - (1000ml-1pc. and 100 ml- 2 pcs.) | Kitchen & Dining',
#  'L1: cello duo medium pu insulated lunch box set of 1 - assorted | 4 sided click locks | Kitchen & Dining',
#  'L1: flair feast 3-pc lunch box set - gray, insulated with handle & spoon | Kitchen & Dining',
#  'L1: pexpo stainless steel lunch box with 3 air-tight containers(1200 ml), 1 spoon & bag, micro pro | Kitchen & Dining',
#  'L1: agaro elite two compartment lunch container, borosilicate glass body, 600ml | Kitchen & Dining',
#  'L1: princeware champ lunch box set of 2 pieces 160 ml+890 ml| 205 x 133 x 54 mm | Kitchen & Dining',
#  'L1: youbee fusion stainless steel lunch box, 1050 ml | Kitchen & Dining',
#  'L1: flair feast 2-pc lunch box set - gray, insulated with handle & spoon | Kitchen & Dining',
#  'L1: signoraware slim high borosilicate glass big lunch box, 1000ml, 1509clear | Kitchen & Dining',
#  'L1: oliveware lovely stylo lunch box - blue | Kitchen & Dining',
#  'L1: magnus vivid solid glass lunch box - 2 round borosilicate fixed clip containers | 400 ml each & bag | Kitchen & Dining',
#  'L1: treo by milton all fresh premier glass box 5pc (3 round containers, 1 bottle, dinning mat) with bag | Kitchen & Dining',
#  'L1: signoraware monarch midday microsafe steel lunch box food grade stainless steel black | Kitchen & Dining',
#  'L1: magnus vivid solid lunch box with bag, 2pc square containers (320 ml each), borosilicate glass tiffin | Kitchen & Dining',
#  'L1: milton mini fun treat super hero lunch box (blue/orange, pack of 1) | Kitchen & Dining',
#  'L1: veigo heatup large - microwave safe stainless steel leakproof tiffin box (630ml) fresh blue | Kitchen & Dining',
#  'L1: veigo jumbo - stainless steel leakproof tiffin w/veg box(950+180 ml) for school,office - aqua blue | Kitchen & Dining',
#  'L1: magnus easy lock stainless steel 520 ml storage container with leakproof lid & bpa free - assorted | Kitchen & Dining',
#  'L1: varmora flat kids lunch box - assorted | 450ml | Kitchen & Dining',
#  'L1: milton decker lunch box (3 microwave safe inner steel containers 450 ml each) with jacket, black | Kitchen & Dining',
#  'L1: varmora twin flat kids lunch box - assorted (450ml+ 450ml) | Kitchen & Dining',
#  'L1: veigo medium stainless steel leakproof snack+tiffin box (330 ml) office,home,school - green | Kitchen & Dining',
#  'L1: magnus glock solid glass lunchbox - vertical pouch & 2 square borosilicate containers | 320 ml each | Kitchen & Dining',
#  'L1: varmora fresh bite kids lunch box - raspberry pink - (1000ml-1pc. and 100 ml- 2 pcs.) | Kitchen & Dining',
#  'L1: oliveware bliss lunch box, 3 stainless steel & leak proof containers bpa free airtight lids - blue | Kitchen & Dining',
#  'L1: milton mini fun treat super hero lunch box (purple/brown, pack of 1) | Kitchen & Dining',
#  'L1: jaypee mini max stainless steel inner with plastic dish inside lunch box , peach, 500 ml | Kitchen & Dining',
#  'L1: magnus microwave safe olive 3 lunch box set | stainless steel containers | insulated bag | Kitchen & Dining',
#  'L1: magnus stainless steel easy lock container - 280 ml - assorted | Kitchen & Dining',
#  'L1: milton pro lunch box (3 inner steel containers, 1 plastic dabba, bottle, & spoons) with bag, maroon | Kitchen & Dining',
#  'L1: magnus vivid solid glass lunch box - round microwave safe borosilicate container | 400 ml x 3 & bag | Kitchen & Dining',
#  'L1: milton pro lunch box (3 inner steel containers, 1 plastic dabba, bottle, & spoons) with bag, blue | Kitchen & Dining',
#  'L1: magnus vivid solid glass lunch box - round microwave-safe borosilicate containers-400 ml x 2 & bag | Kitchen & Dining',
#  'L1: cello mf all in one lunch box 5 with bag, black | 3 containers steel, 1 pickle box and 1 bottle | Kitchen & Dining',
#  'L1: varmora twin flat kids lunch box (450ml + 450ml) - assorted | Kitchen & Dining',
#  'L1: hoom universal design plastic lunch box set.-hmgslb 96004-uni [blue] | Kitchen & Dining',
#  'L1: marvel avengers lunch box inside stainless steel.-hmhtlb 73371-av | Kitchen & Dining',
#  'L1: khatana oval dd lunch box 2 | 800 ml | Kitchen & Dining',
#  'L1: veigo heatup medium- microwave safe stainless steel leakproof tiffin/snack box(330ml) militarygreen | Kitchen & Dining',
#  'L1: magnus glock solid lunch box with bag, 3pc square containers (320 ml each), borosilicate glass tiffin | Kitchen & Dining',
#  'L1: magnus vivid solid lunch box with bag, 1 ss bottle, 3pc square containers (320 ml each), glass tiffin | Kitchen & Dining',
#  'L1: magnus glock solid glass lunch box | flat pouch & 2 square microwave safe containers | 320ml each | Kitchen & Dining',
#  'L1: signoraware double decker special steel lunch box with bag, 350ml+350ml+650ml, set/3, 3551blue | Kitchen & Dining',
#  'L1: magnus avanza 3 prime lunch box set | stainless steel | airtight leakproof | insulated cover | Kitchen & Dining',
#  'L1: signoraware feast oval steel lunch box food grade stainless steel blue | Kitchen & Dining',
#  'L1: signoraware director borosilicate glass lunch box with bag, 320ml*3, set of 3, 1501clear | Kitchen & Dining',
#  'L1: veigo maxosteel - stainless steel leakproof box (450 ml) school, snacks, outdoor - violet | Kitchen & Dining',
#  'L1: borosil square lunch box with bag (320 ml + 320 ml) | borosilicate glass | Kitchen & Dining',
#  'L1: all time salad lunch box with dip container | 1450 ml - assorted | Kitchen & Dining',
#  'L1: milton steely deluxe mini inner steel kids tiffin box, 400 ml, pink, 1 pc | Kitchen & Dining',
#  'L1: signoraware double decker special steel lunch box with bag, 350ml+350ml+650ml, set/3, 3551red | Kitchen & Dining',
#  'L1: milton savor lunch tiffin (3 microwave safe inner steel containers, 180/320/450 ml; | Kitchen & Dining',
#  'L1: milton double decker lunch box, set of 3, (450 ml, 280 ml, 280 ml) red, microwave safe | Kitchen & Dining',
#  'L1: jensons stainless steel easy trio meal lunch box | Kitchen & Dining',
#  'L1: veigo small stainless steel leakproof dabbi for chutney, sauce, snacks + kids & adults(180 ml) red | Kitchen & Dining',
#  'L1: signoraware compact steel lunch box (big) - assorted | Kitchen & Dining',
#  'L1: jaypee steel tek jr. insulated airtight lunch box mickey mouse printed for school kids, pin, 400 ml | Kitchen & Dining',
#  'L1: veigo heatup large - microwave safe stainless steel leakproof tiffin box (630ml) peach fuzz | Kitchen & Dining',
#  'L1: signoraware compact steel lunch box (small) food grade stainless steel red | Kitchen & Dining',
#  'L1: signoraware executive borosilicate glass lunch box round 3 pcs 1504clear | Kitchen & Dining',
#  'L1: flair magic meal 650 ml stainless steel lunch box set blue | Kitchen & Dining',
#  'L1: flair magic meal 900 ml stainless steel lunch box set pink | Kitchen & Dining',
#  'L1: jaypee plus hott line electric lunch box, 3 stainless steel container, dark blue | Kitchen & Dining',
#  'L1: oliveware lovely stylo lunch box - red | Kitchen & Dining',
#  'L1: magnus olive 3 prime microwave safe lunch box set | stainless steel steam lock containers & pouch | Kitchen & Dining',
#  'L1: omega stainless steel tiffin box with clip | lunch box for office, school, etc | 2 compartments | Kitchen & Dining',
#  'L1: nayasa steel super lock l.b. | Kitchen & Dining',
#  'L1: flair trendy dlx insulated lunch box large 900 ml (purple) | Kitchen & Dining',
#  'L1: marvel avengers lunch box inside stainless steel.-hmrplb 73373-av | Kitchen & Dining',
#  'L1: magnus neo 5 lunch tiffin - 3 microwave safe inner steel containers dabba bottle spoon and fork | Kitchen & Dining',
#  'L1: bay6 microwave-safe airtight lunch box container - 400 ml - (2pc) | Kitchen & Dining',
#  'L1: bevzilla assorted instant milkshake 10 cubes pack with organic date palm jaggery | Tea, Coffee & More',
#  'L1: quinze rubber lpg gas stove legs with inner stainless steel nut - bolt (black) - set of 4 pieces | Kitchen & Dining',
#  'L1: mancode fitkari after shave gel cool | Fragrances & Grooming',
#  'L1: fackelmann bamboo rice spoon | ideal for serving rice, curries & vegetables | Kitchen & Dining',
#  'L1: vinay trading wooden spoon 16 cm 30 pc combo | Kitchen & Dining',
#  'L1: eco soul set of 3 | bamboo cooking utensils | Kitchen & Dining',
#  'L1: wheel green lemon & jasmine detergent powder | Cleaning Essentials',
#  'L1: surf excel easy wash detergent powder | Cleaning Essentials',
#  'L1: tide plus detergent washing powder | jasmine & rose | Cleaning Essentials',
#  'L1: rin detergent powder | Cleaning Essentials',
#  'L1: surf excel quick wash detergent powder | Cleaning Essentials',
#  'L1: tide plus detergent washing powder | lemon & mint | Cleaning Essentials',
#  'L1: surf excel easy wash detergent powder 1 kg combo | Cleaning Essentials',
#  'L1: sunlight detergent powder | Cleaning Essentials',
#  'L1: more light extra power detergent powder | Cleaning Essentials',
#  'L1: wheel green lemon & jasmine detergent powder 1 kg combo | Cleaning Essentials',
#  'L1: surf excel quick wash detergent powder 500 g combo | Cleaning Essentials',
#  'L1: ariel complete detergent powder | removes 100 tough stains in 1 wash | Cleaning Essentials',
#  'L1: wheel detergent powder | Cleaning Essentials',
#  'L1: rin detergent powder 1 kg combo | Cleaning Essentials',
#  'L1: eggoz egg nuggets | Frozen Food',
#  'L1: galangal 100gms | Fruits & Vegetables',
#  'L1: britannia atta kulcha bread (5 pcs) | Dairy, Bread & Eggs',
#  'L1: english oven kulcha bread | Dairy, Bread & Eggs',
#  'L1: harvest gold kulcha bread | Dairy, Bread & Eggs',
#  'L1: the health factory zero maida kulcha bread | Dairy, Bread & Eggs',
#  'L1: bonn kulcha bread | Dairy, Bread & Eggs',
#  'L1: bonn atta kulcha bread | Dairy, Bread & Eggs',
#  'L1: english oven atta kulcha bread | Dairy, Bread & Eggs',
#  'L1: britannia atta kulcha bread (5 pcs) 250 g combo | Dairy, Bread & Eggs',
#  'L1: britannia kulcha | Dairy, Bread & Eggs',
#  'L1: english oven kulcha bread combo | Dairy, Bread & Eggs',
#  'L1: harpic toilet cleaner liquid - original | Cleaning Essentials',
#  'L1: harpic bleach toilet cleaner liquid | Cleaning Essentials',
#  'L1: dew fresh toilet cleaner liquid | Cleaning Essentials',
#  'L1: harpic toilet cleaner liquid - jasmine | Cleaning Essentials',
#  'L1: bay6 disinfectant toilet cleaner | Cleaning Essentials',
#  'L1: harpic toilet cleaner liquid - lemon | Cleaning Essentials',
#  'L1: harpic white and shine bleach | Cleaning Essentials',
#  'L1: domex toilet cleaner liquid, lime fresh | Cleaning Essentials',
#  'L1: sanifresh toilet cleaner | Cleaning Essentials',
#  'L1: domex toilet cleaner liquid, ocean fresh | Cleaning Essentials',
#  'L1: mr muscle toilet cleaner | Cleaning Essentials',
#  'L1: dew fresh toilet cleaner | Cleaning Essentials',
#  'L1: harpic toilet cleaner liquid - marine | Cleaning Essentials',
#  'L1: domex fresh guard disinfectant toilet cleaner liquid ocean freshness for 100 flushes | Cleaning Essentials',
#  'L1: harpic bleach toilet cleaner liquid 500 ml combo | Cleaning Essentials',
#  'L1: glenzo toilet cleaner | Cleaning Essentials',
#  'L1: gainda disinfectant toilet cleaner | Cleaning Essentials',
#  'L1: bay6 disinfectant toilet cleaner | pack of 2 | Cleaning Essentials',
#  'L1: domex toilet cleaner liquid, ocean fresh 1 l combo | Cleaning Essentials',
#  'L1: kleenest toilet cleaner rose | Cleaning Essentials',
#  'L1: domex toilet cleaner liquid, lime fresh(1l) & domex toilet cleaner liquid, ocean fresh(1l) combo | Cleaning Essentials',
#  'L1: jk a4 copier paper white sheet (75 gsm) | Stationery & Books',
#  'L1: jk easy copier a4 70 gsm(500 sheets) | Stationery & Books',
#  'L1: satia a4 copier paper 70 gsm, 500 sheets | Stationery & Books',
#  'L1: ik a4 copier paper 70 gsm, 500 sheets | Stationery & Books',
#  'L1: satia a4 copier paper 65 gsm, 500 sheets | Stationery & Books',
#  'L1: eva foam glitter sheets a4 size, assorted colours | Stationery & Books',
#  'L1: jk excel bond a4 90 gsm(100 sheets) | Stationery & Books',
#  'L1: dev snacks achappam | Munchies',
#  'L1: schweppes original ginger ale can | Cold Drinks & Juices',
#  'L1: schweppes original ginger ale can 300 ml combo | Cold Drinks & Juices',
#  'L1: gunsberg ginger ale can | Cold Drinks & Juices',
#  "L1: jimmy's ginger ale | Cold Drinks & Juices",
#  'L1: sepoy & co. ginger ale | Cold Drinks & Juices',
#  'L1: bombay 99 ginger ale can | Cold Drinks & Juices',
#  'L1: gunsberg grapefruit ale | Cold Drinks & Juices',
#  'L1: borecha ginger ale | Cold Drinks & Juices',
#  'L1: black & white ginger ale can | Cold Drinks & Juices',
#  'L1: himalaya herbals baby cream | Baby Care',
#  "L1: johnson's baby cream | Baby Care",
#  "L1: johnson's milk + rice cream | Baby Care",
#  'L1: himalaya baby cream | Baby Care',
#  'L1: mamaearth milky soft baby face cream with muru muru butter | Baby Care',
#  'L1: baby sebamed cream extra soft | ph 5.5| ideal for dry skin | Baby Care',
#  'L1: himalaya gentle baby shampoo | Baby Care',
#  'L1: baby sebamed gentle wash | ph 5.5 | baby body wash | soap free| tear free | Baby Care',
#  'L1: aveeno baby daily moisturising wash & shampoo | Baby Care',
#  'L1: baby sebamed gentle wash | ph 5.5 | baby body wash | soap free | tear free | Baby Care',
#  'L1: himalaya extra moisturizing baby wash | Baby Care',
#  'L1: himalaya head to toe baby wash with pure cow ghee & ph 5.5 | Baby Care',
#  'L1: mamaearth milky soft body wash for babies | Baby Care',
#  "L1: johnson's baby ttt bath | Baby Care",
#  'L1: mamaearth deeply nourishing body wash for babies | Baby Care',
#  'L1: aveeno baby daily moisture wash & shampoo | Baby Care',
#  'L1: leeks | Fruits & Vegetables',
#  'L1: leek | Fruits & Vegetables',
#  'L1: frubon elaichi shrikhand | Dairy, Bread & Eggs',
#  'L1: amul shrikhand badam pista | Dairy, Bread & Eggs',
#  'L1: chitale full cream shrikhand amba (mango) | Dairy, Bread & Eggs',
#  'L1: amul mango shrikhand | Dairy, Bread & Eggs',
#  'L1: amul shrikhand kesar | Dairy, Bread & Eggs',
#  'L1: amul shrikhand elaichi | Dairy, Bread & Eggs',
#  'L1: mee mee mild baby liquid laundry detergent - one drop cleaning | Baby Care',
#  'L1: luvlap baby laundry detergent refill pack | Baby Care',
#  'L1: luvlap baby laundry detergent | Baby Care',
#  'L1: mee mee anti-bacterial baby laundry detergent - one drop cleaning | Baby Care',
#  'L1: mee mee anti-bacterial baby liquid cleanser refill pack | Baby Care',
#  'L1: mother sparsh plant powered baby laundry detergent refill pack | Baby Care',
#  'L1: mother sparsh plant powered baby laundry liquid detergent with bio enzymes and eucalyptus oil | Baby Care',
#  'L1: chicco laundry detergent fresh spring | Baby Care',
#  'L1: mccain variety pack | Frozen Food',
#  'L1: mccain potato cheese shotz | Frozen Food',
#  'L1: itc master chef chili garlic potato bites super saver | Frozen Food',
#  'L1: godrej yummiez potato cheese bites | Frozen Food',
#  'L1: mccain chilli garlic potato bites nuggets 420 g combo | Frozen Food',
#  'L1: mr. munchies paneer cheese corn roll | Frozen Food',
#  'L1: goeld mac and cheese pops | Frozen Food',
#  'L1: mustard leaves (sarso saag) | Fruits & Vegetables',
#  'L1: bay6 steel whisk with pipe handle | Kitchen & Dining',
#  'L1: kuber industries multiuses 25cm stainless steel kitchen utensil wire whisk | egg beater (silver) | Kitchen & Dining',
#  'L1: jassco stainless steel whisk | Kitchen & Dining',
#  'L1: petals stainless steel egg whisk-beater-cake batter whisker 30cm | Kitchen & Dining',
#  'L1: ash gourd | Fruits & Vegetables',
#  'L1: babila baby brush with comb (set of 2 pcs)-bc-v01 | Baby Care',
#  'L1: bottle gourd | Fruits & Vegetables',
#  'L1: organic bottle gourd | Fruits & Vegetables',
#  "L1: the baker's dozen zero maida breadsticks (grissini) baked snack no palm oil no preservatives 100% wholewheat | Munchies",
#  'L1: waves prawn crackers | Meats, Fish & Eggs',
#  'L1: waves tunafish crackers | Meats, Fish & Eggs',
#  'L1: chana saag | Fruits & Vegetables',
#  'L1: saya pen stand | Stationery & Books',
#  'L1: saya assorted pen stand - classic | Stationery & Books',
#  'L1: chrome 9632 3 compartment metal mesh desk organizer | Stationery & Books',
#  'L1: chrome 9608 plastic pen stand - assorted | Stationery & Books',
#  'L1: chrome 9631 metal mesh 4 compartment pen stand desk organizer. | Stationery & Books',
#  'L1: chrome 9692 plastic pen stand | Stationery & Books',
#  'L1: itc master chef medium prawns peeled & deveined | Frozen Food',
#  'L1: relish prawns peeled & deveined | Meats, Fish & Eggs',
#  'L1: itc master chef prawns large peeled & deveined | Frozen Food',
#  'L1: godrej yummiez medium prawns | Frozen Food',
#  'L1: itc master chef medium prawns peeled & deveined 200 g combo | Frozen Food',
#  'L1: post-it sticky notes pad | multicolor| 3inch x 3inch| 100 notes | Stationery & Books',
#  'L1: post-it sticky notes - 25 mm x 76 mm | multicolour | paper | rectangular | 150 sheets | Stationery & Books',
#  'L1: post-it sticky notes - 3" x 3" | multicolour | paper | square | 200 sheets | Stationery & Books',
#  'L1: saya stick-eee page markers | 1 x 3 x 3 inches | Stationery & Books',
#  'L1: tawa plain paratha - pack of 2 | Zepto Cafe',
#  'L1: wheat chapati - pack of 3 | Zepto Cafe',
#  'L1: wheat chapati - pack of 10 | Zepto Cafe',
#  'L1: homeharmony rat/mouse/rodent trap cage rustic copper | Cleaning Essentials',
#  'L1: rosemary | Fruits & Vegetables',
#  'L1: dabur lal dant manjan powder 100g | Bath & Body',
#  'L1: vicco vajradanti ayurvedic toothpaste 100g | Bath & Body',
#  'L1: baby corn | Fruits & Vegetables',
#  'L1: relish bata whole and cleaned | Meats, Fish & Eggs',
#  'L1: bitter gourd | Fruits & Vegetables',
#  'L1: organic bitter gourd | Fruits & Vegetables',
#  "L1: d'lecta cream cheese | Dairy, Bread & Eggs",
#  'L1: milky mist cream cheese spread- tub | Dairy, Bread & Eggs',
#  "L1: d'lecta cream cheese 150 g combo | Dairy, Bread & Eggs",
#  'L1: ds ganpati plastic modak & chocolate mould set, 4 sizes, for homemade sweets | Kitchen & Dining',
#  'L1: alt co oats milk | Cold Drinks & Juices',
#  'L1: alt co oat beverage | Cold Drinks & Juices',
#  'L1: only earth oats beverage unsweetened | non-dairy drink | lactose free | Cold Drinks & Juices',
#  'L1: so good plant based oat beverage unsweetened tetrapack | Cold Drinks & Juices',
#  'L1: only earth oats belgian chocolate milk shake tetrapack | Cold Drinks & Juices',
#  'L1: only earth oats strawberry plant-based shake | Cold Drinks & Juices',
#  'L1: only earth oats alphonso mango plant-based shake | Cold Drinks & Juices',
#  'L1: rajnigandha flavoured pan masala | Paan Corner',
#  'L1: rajnigandha flavoured pan masala (pack of 3) | Paan Corner',
#  'L1: rajnigandha flavoured pan masala (pack of 10) | Paan Corner',
#  'L1: english oven burger bun | Dairy, Bread & Eggs',
#  'L1: the health factory zero maida burger bun | Dairy, Bread & Eggs',
#  'L1: bonn creme bun vanilla | Dairy, Bread & Eggs',
#  'L1: harvest gold burger buns | Dairy, Bread & Eggs',
#  'L1: harvest gold atta burger buns | Dairy, Bread & Eggs',
#  'L1: modern supreme burger bun | Dairy, Bread & Eggs',
#  "L1: the baker's dozen zero maida burger buns no palm oil no preservative 100% wholehwheat | Dairy, Bread & Eggs",
#  'L1: bonn sesame burger buns | Dairy, Bread & Eggs',
#  'L1: english oven burger bun 6 pieces | Dairy, Bread & Eggs',
#  'L1: english oven atta burger bun | Dairy, Bread & Eggs',
#  'L1: brano tilli burger buns | Dairy, Bread & Eggs',
#  'L1: britannia burger bun with sesame seed | Dairy, Bread & Eggs',
#  'L1: modern cremtreat vanilla cream bun 50 g combo | Dairy, Bread & Eggs',
#  'L1: english oven burger bun 200 g combo | Dairy, Bread & Eggs',
#  'L1: every day burger buns | Dairy, Bread & Eggs',
#  'L1: modern cremtreat chocolate cream bun 50 g combo | Dairy, Bread & Eggs',
#  "L1: nanda's vanilla cream bun 60 g combo | Dairy, Bread & Eggs",
#  'L1: kitty burger buns | Dairy, Bread & Eggs',
#  'L1: moreish burger bun | Dairy, Bread & Eggs',
#  'L1: every day milk buns | Dairy, Bread & Eggs',
#  'L1: high protein burger bun (no maida) - made with mp sharbati wheat | Dairy, Bread & Eggs',
#  'L1: the health factory zero maida burger bun 120 g combo | Dairy, Bread & Eggs',
#  'L1: amul a2 buffalo fresh milk | Dairy, Bread & Eggs',
#  'L1: gokul buffalo full cream fresh milk (pouch) | Dairy, Bread & Eggs',
#  "L1: sid's farm a2 buffalo fresh milk (pouch) | Dairy, Bread & Eggs",
#  'L1: sids farm a2 buffalo double toned milk | Dairy, Bread & Eggs',
#  'L1: heritage fresh buffalo milk(pouch) | Dairy, Bread & Eggs',
#  'L1: doodhvale farms royal a2 buffalo fresh milk | Dairy, Bread & Eggs',
#  'L1: gokul buffalo full cream fresh milk (pouch) 500 ml combo | Dairy, Bread & Eggs',
#  'L1: britannia fruit bread | Dairy, Bread & Eggs',
#  'L1: modern fruity bread | Dairy, Bread & Eggs',
#  'L1: bonn frooty bread | Dairy, Bread & Eggs',
#  'L1: brano fruit bread | Dairy, Bread & Eggs',
#  'L1: english oven fruit bread | Dairy, Bread & Eggs',
#  "L1: chheda's kachori | Munchies",
#  "L1: haldiram's kachori | Munchies",
#  'L1: namaskaram kachori | Munchies',
#  'L1: measuring cup pack of 5 | Kitchen & Dining',
#  'L1: joyo plastics m. w. safe multipurpose mixing bowls - set of 4 ( assorted ) | Kitchen & Dining',
#  'L1: all time picnic pasta bowl set of 2 (1200 ml x 2) (assorted color) (2 pc set) | Kitchen & Dining',
#  'L1: cello ornella toughened glass mixing bowl 1000ml | Kitchen & Dining',
#  'L1: cuba mixing bowl with lid | 1000 ml | set of 2 | Kitchen & Dining',
#  'L1: jensons stainless steel deep mixing bowl 18 cm | Kitchen & Dining',
#  'L1: jensons stainless steel deep mixing bowl 20 cm | Kitchen & Dining',
#  'L1: embassy premium mixing bowl / multipurpose bowl, 2800 ml (size 4), stainless steel | Kitchen & Dining',
#  'L1: bay6 premium imported borosilicate glass mixing bowl -750 ml - set of 2 | Kitchen & Dining',
#  'L1: embassy premium mixing bowl / multipurpose bowl, 2000 ml (size 2), stainless steel | Kitchen & Dining',
# ...
#  'L1: mental maths - mathematics activity book 1 for class 1+, age 5+ years | Stationery & Books',
#  'L1: brain activity book for kids - 1008 activities for 5-8 years old | early learning | Stationery & Books',
#  'L1: 108 moral stories (illustrated) - story book for kids | Stationery & Books',
#  'L1: phonic reader (illustrated) (set of 6 books) - story books for kids | Stationery & Books',
#  'L1: mental maths - mathematics activity book 2 for class 2+, age 6+ years | Stationery & Books',
#  'L1: 108 stories from vedas, puranas and upanishads for children (illustrated) - story book | Stationery & Books',
#  'L1: 108 fairy tales (illustrated) - story book for kids | Stationery & Books',
#  'L1: 108 indian mythology stories (illustrated) - story book for kids | Stationery & Books',
#  'L1: math activity book for kids - 200+ activities for age 3+ years - counting - addition - subtraction | Stationery & Books',
#  'L1: my first learning library - boxset of board books - 8 topics gift set for kids (illustrated) | Stationery & Books',
#  'L1: shlokas and mantras and hanuman chalisa for kids age 2+ (illustrated) (set of 2 books) | Stationery & Books',
#  'L1: brain boosting activity book set (set of 4 books) | Stationery & Books',
#  'L1: story books for kids - fairy tales (illustrated) (set of 12 books) | Stationery & Books',
#  'L1: mythology tales - story book for kids (illustrated) (set of 10 books) | Stationery & Books',
#  'L1: my first all in one board book | Stationery & Books',
#  'L1: 108 ramayana stories | illustrated | bedtime stories for kids | age 3-10 | Stationery & Books',
#  'L1: introduction to coding for kids - brain activity book for kids - age 6+ | Stationery & Books',
#  'L1: mental maths - math activity book 4 | age 8+ | prime numbers | multiples | hcf | lcf | Stationery & Books',
#  'L1: my first all in one : bilingual picture book for kids hindi-english | Stationery & Books',
#  'L1: good habits for kids - illustrated board book for children | age 2-6 - manners book | Stationery & Books',
#  'L1: ultimate vehicles scissors skills activity book | 4 - 7y | with child- safe scissors, games & mask | Stationery & Books',
#  'L1: mental maths - mathematics activity book 3 for class 3+, age 7+ | Stationery & Books',
#  'L1: varnmala - picture book for toddlers | hindi alphabets | age 2-5 | Stationery & Books',
#  'L1: mental maths - mathematics activity book 5 for class 5+, age 9+ - math activity book for children | Stationery & Books',
#  'L1: life lessons - story books for kids (set of 6 books) (illustrated) | Stationery & Books',
#  'L1: math activity book for kids | 200+ multiplication and division for age 5+ years | math activities | Stationery & Books',
#  'L1: story books for kids | set of 5 - world scientists | biographies for kids | age 6-10 | Stationery & Books',
#  'L1: sherlock holmes | illustrated | | story book for kids | english short stories for children | Stationery & Books',
#  'L1: my first 8-in-1 illustrated library | alphabet | numbers | animals | shapes | age 0-2 | Stationery & Books',
#  'L1: story books for kids - world classic (abridged) (set of 10 books) (illustrated) | Stationery & Books',
#  'L1: story books for kids (set of 4 books) - illustrated board book for children | Stationery & Books',
#  'L1: story books for kids - fairy tales (illustrated) (set of 20 books) | Stationery & Books',
#  'L1: dreamland my magical unicorn sticker and activity book for kids | age 3 - 8 years | Stationery & Books',
#  'L1: activity book for kids - mazes | early learning for toddlers | nursery | pre-school | Stationery & Books',
#  'L1: water magic unicorn- with water pen - use over and over again | Stationery & Books',
#  'L1: dreamland make a pretty face with 100+ stickers | Stationery & Books',
#  "L1: kids' first library box set of 10 board books l gift set for kids | Stationery & Books",
#  'L1: 108 panchatantra story book for kids (hindi) (illustrated) | Stationery & Books',
#  'L1: nursery rhymes for kids - board book | johnny johnny | hot cross buns | age 0-2 | Stationery & Books',
#  'L1: story books for kids - first reader (illustrated) (set of 6 books) (hindi) | Stationery & Books',
#  'L1: story books for kids (set of 5 books) ndian scientists biographies for children | Stationery & Books',
#  'L1: sticker books (set of 4 books) - flags - space - dinosaurs - experiences | Stationery & Books',
#  'L1: shlokas and mantras for kids - illustrated board book for children - age 0 - 2 years | Stationery & Books',
#  'L1: cursive handwriting - sentence practice workbook | Stationery & Books',
#  'L1: vedic mathematics | indian classics | | vedic maths activities | vedic maths for children | Stationery & Books',
#  'L1: alphabets writing book - small letters (practice) | Stationery & Books',
#  'L1: kids encyclopedia | illustrated | human body | questions and answer with pictures | knowledge book | Stationery & Books',
#  'L1: abc board book for kids age 0-2 years picture book to learn alphabet | Stationery & Books',
#  'L1: 108 festival stories for kids (illustrated) - story book for kids | Stationery & Books',
#  'L1: numbers writing book 1-100 (practice) - learn and practice | Stationery & Books',
#  'L1: story books for kids - first reader (illustrated) (set of 12 books) | Stationery & Books',
#  'L1: activity book for kids | 400+ math activities | addition, subtraction, multiplication, division | Stationery & Books',
#  'L1: my first book of patterns pencil control: patterns practice book for kids (pattern writing) | Stationery & Books',
#  'L1: stories from ramayana and mahabharata (set of 2) (illustrated) - story books for kids | Stationery & Books',
#  'L1: story books for kids - bedtime stories | set of 10 | moral stories | age 3-10 | Stationery & Books',
#  'L1: my first book of patterns capital letters write and practice patterns and captital letters a to z | Stationery & Books',
#  'L1: my world (set of 10 books) - science knowledge books for kids | Stationery & Books',
#  'L1: numbers writing book 1-50 | practice numbers | age 2-5 | Stationery & Books',
#  'L1: the old man and the sea | ernest hemingway - children’s classic | Stationery & Books',
#  'L1: 108 akbar and birbal stories (illustrated) (hindi) - story book for kids | Stationery & Books',
#  'L1: baby my first cloth book fruit & vegetables with squeaker & crinkle paper, non-toxic | Stationery & Books',
#  'L1: bible stories | illustrated | story book for kids | bedtime stories | moral stories | Stationery & Books',
#  'L1: story book for kids (set of 10 books) - panchatantra stories | Stationery & Books',
#  'L1: brain games for kids - teasers & puzzles | cognitive development | age 6+ | Stationery & Books',
#  'L1: my first shaped board book- illustrated lord shiva hindu mythology picture book for kids age 2+ | Stationery & Books',
#  'L1: story books for kids (set of 5 books) (illustrated) - indian freedom fighters | Stationery & Books',
#  'L1: shlokas and mantras books for kids |set of 2 | - illustrated book with shloka activity for kids | Stationery & Books',
#  'L1: my first goddesses (illustrated) (set of 5 books) - story books for kids | Stationery & Books',
#  'L1: kids encyclopedia | illustrated | general knowledge | knowledge book for kids | gk for kids | Stationery & Books',
#  'L1: 505 activities for kids | Stationery & Books',
#  'L1: hindi sulekh - barakhadi - handwriting practice workbook for kids | Stationery & Books',
#  'L1: hindi sulekh varnamala l hindi handwriting practice book for kids | Stationery & Books',
#  'L1: 201 amazing activity book - fun activities and puzzles for children spot the difference | Stationery & Books',
#  'L1: crossword puzzles book 1 ideal retreat for thinking minds | Stationery & Books',
#  'L1: story book for kids (set of 10 books) (illustrated) (hindi) - moral stories | Stationery & Books',
#  "L1: kids' first 4 in 1 board book l colors, shapes, alphabet, numbers l early learning | Stationery & Books",
#  'L1: beyond good & evil - friedrich nietzsche | Stationery & Books',
#  'L1: story book for kids - 108 moral stories | illustrated | hindi | age 3-10 | Stationery & Books',
#  "L1: ching's secret schezwan chutney | spicy and tangy | dip | spread | cook | Packaged Food",
#  'L1: id coconut chutney | Dairy, Bread & Eggs',
#  'L1: id peanut chutney | Dairy, Bread & Eggs',
#  'L1: id tomato chutney | Dairy, Bread & Eggs',
#  'L1: masterchow hot and spicy schezwan chutney | Packaged Food',
#  "L1: mother's recipe tamrind date chutney | Packaged Food",
#  'L1: id coriander chutney | Dairy, Bread & Eggs',
#  'L1: khetika coconut chutney | Dairy, Bread & Eggs',
#  'L1: id fresh sambar (heat and eat) | Dairy, Bread & Eggs',
#  "L1: amma's special coconut chutney | Dairy, Bread & Eggs",
#  'L1: moi soi gochujang korean chilli paste | Packaged Food',
#  'L1: khetika peanut chutney | Dairy, Bread & Eggs',
#  'L1: dabur hommade coriander chutney | Packaged Food',
#  "L1: ammamma's peanut chutney | Dairy, Bread & Eggs",
#  'L1: chings secret schezwan chutney, spicy & tangy, dip, spread, cook(250gms) & chings secret schezwan chutney, spicy & tangy, dip, spread, cook(140gms) combo | Packaged Food',
#  "L1: mother's recipe desi schezwan chutney | Packaged Food",
#  'L1: daishik tamarind chutney | Packaged Food',
#  'L1: masterchow momo chutney | Packaged Food',
#  "L1: mother's recipe bhel puri chutney | Packaged Food",
#  'L1: hillers schezwan hot chutney | Packaged Food',
#  'L1: daishik coconut garlic chutney | Packaged Food',
#  'L1: daishik green chutney | Packaged Food',
#  'L1: masterchow chilli garlic chutney | Packaged Food',
#  'L1: daishik white coconut chutney | Packaged Food',
#  'L1: britannia nutrichoice digestive zero biscuits | Biscuits',
#  "L1: mcvitie's digestive high fibre biscuits with goodness of wholewheat,super saver family pack | Biscuits",
#  'L1: britannia nutri choice digestive biscuits packet combo | Biscuits',
#  'L1: britannia nutrichoice digestive high fibre biscuits | 0% maida 100 g combo | Biscuits',
#  'L1: parle nutricrunch classic digestive cookies | Biscuits',
#  'L1: sunfeast farmlite 5 seed high fibre digestive biscuit | Biscuits',
#  'L1: unibic oatmeal digestive cookies | Biscuits',
#  'L1: britannia nutrichoice 5 grain digestive high-fibre biscuits | Biscuits',
#  'L1: camlin deluxe large stamp pad, colour - violet | Stationery & Books',
#  'L1: canon ink bottle gi-790b black | Stationery & Books',
#  "L1: the baker's dozen lavash flatbread healthy snacks(100gms) & veeba cheese and jalapeno dip(300gms) combo | Munchies",
#  'L1: lotus stem | Fruits & Vegetables',
#  'L1: papaya | Fruits & Vegetables',
#  'L1: papaya lady red/poppadi pandu/boppas pandu | Fruits & Vegetables',
#  'L1: papaya small | Fruits & Vegetables',
#  'L1: organic papaya | Fruits & Vegetables',
#  'L1: daily good pistachios california salted 100 g combo | Munchies',
#  'L1: bazana roasted salted pistachios | Munchies',
#  'L1: yogabar premium pista | crunchy pistachios i rich in protein, fibre, gluten free & low calories | Munchies',
#  'L1: plum imported | Fruits & Vegetables',
#  'L1: plum imported premium | Fruits & Vegetables',
#  'L1: lushomes green check oven mitt & pot holder set, 2 pcs glove 6x13, 2 pcs pot holder 8x8 | Kitchen & Dining',
#  'L1: lushomes 4 pack multi check cotton oven mitt & pot holder set pcs glove 6x13, 2 pcs pot holder 8x8 | Kitchen & Dining',
#  'L1: lushomes 4 pack red check oven mitt & pot holder set, 2 pcs glove 6x13, 2 pcs pot holder 8x8 | Kitchen & Dining',
#  'L1: doms wow kit | Stationery & Books',
#  'L1: doms exam essential kit - complete exam kit | Stationery & Books',
#  'L1: cello school kit | Stationery & Books',
#  'L1: apsara writing kit | Stationery & Books',
#  'L1: apsara art kit | Stationery & Books',
#  'L1: luxor smart artist kit | drawing book | sketching set | colouring set | stationary set | Stationery & Books',
#  'L1: doms fun fiesta kits | Stationery & Books',
#  'L1: flair creative marvel avenger kit 50 | Stationery & Books',
#  'L1: flair creative disney micky mouse kit 50 | Stationery & Books',
#  'L1: flair creative disney princes kit 200 | Stationery & Books',
#  'L1: flair creative disney micky mouse kit 200 | Stationery & Books',
#  'L1: riversoft tap extender for kitchen sink | 360 degree rotation | water saving nozzle (chrome) | Kitchen & Dining',
#  'L1: espresso tonic | Zepto Cafe',
#  'L1: dnv appalam | Packaged Food',
#  "L1: mother's recipe appalam | Packaged Food",
#  "L1: jimmy's appalam | Packaged Food",
#  "L1: jimmy's appalam mini | Packaged Food",
#  "L1: jimmy's appalam masala poo | Packaged Food",
#  "L1: mother's recipe appalam 100 g combo | Packaged Food",
#  'L1: relish basa fillet / apollo fish | Meats, Fish & Eggs',
#  'L1: relish basa / pangas fillet | Meats, Fish & Eggs',
#  'L1: black night shade leaves (manathakkali keerai) | Fruits & Vegetables',
#  'L1: fnp vibrant orchid flower bouquet | Fruits & Vegetables',
#  'L1: fnp festive bloom bouquet | Fruits & Vegetables',
#  'L1: fnp mystical mix carnations flower bouquet | Fruits & Vegetables',
#  'L1: korean cream cheese bun | Zepto Cafe',
#  'L1: tasty nibbles white meat tuna flakes in water | Meats, Fish & Eggs',
#  'L1: tasty nibbles light meat tuna flakes in water salt added canned | Meats, Fish & Eggs',
#  'L1: tasty nibbles white meat tuna chunks in water salt added | Meats, Fish & Eggs',
#  'L1: tasty nibbles light meat tuna flakes in water canned | Meats, Fish & Eggs',
#  'L1: tasty nibbles light meat tuna flakes in sunflower oil canned | Meats, Fish & Eggs',
#  'L1: tasty nibbles white meat tuna flakes in water salt added | Meats, Fish & Eggs',
#  'L1: tasty nibbles masala fried prawns | Meats, Fish & Eggs',
#  'L1: relish chicken mince | Meats, Fish & Eggs',
#  'L1: zorabian chicken mince | Meats, Fish & Eggs',
#  'L1: meatzza fresh-chicken-mince | Frozen Food',
#  'L1: relish mutton mince | Meats, Fish & Eggs',
#  'L1: sneha supercool fz minced chicken | Frozen Food',
#  'L1: nicotex mint plus 2 mg | Paan Corner',
#  'L1: nicotex mint plus 2mg tin 29’s | Paan Corner',
#  'L1: nicotex paan 2 mg | Paan Corner',
#  'L1: cipla nicotex gum fruit burst | Paan Corner',
#  'L1: cipla nicotex gum ultra mint | Paan Corner',
#  'L1: ryze nicotine gums 2mg (royal paan) gums single pack - 9 gum blister | Paan Corner',
#  'L1: ryze nicotine gums 2mg (frosty mint) gums single pack - 9 gum blister | Paan Corner',
#  'L1: ryze nicotine gums 2mg (fresh fennel) gums single pack - 9 gum blister | Paan Corner',
#  'L1: amul masti spiced buttermilk | Cold Drinks & Juices',
#  'L1: amul probiotic buttermilk | Cold Drinks & Juices',
#  'L1: amul probiotic tadka chaas | Cold Drinks & Juices',
#  'L1: mother dairy probiotic tadka chach | Cold Drinks & Juices',
#  'L1: heritage a-one probiotic buttermilk - spiced | Cold Drinks & Juices',
#  'L1: frubon masala chhach | Cold Drinks & Juices',
#  'L1: frubon matka chhach (plain chhach) | Cold Drinks & Juices',
#  'L1: akshayakalpa organic probiotic buttermilk - plain | Cold Drinks & Juices',
#  'L1: amul masti spiced buttermilk 200 ml combo | Cold Drinks & Juices',
#  'L1: akshayakalpa - organic probiotic buttermilk spiced | Cold Drinks & Juices',
#  'L1: amul probiotic tadka chaas 270 ml combo | Cold Drinks & Juices',
#  'L1: sumul dairy probiotic unsalted buttermilk | Cold Drinks & Juices',
#  'L1: amul probiotic buttermilk 460 ml combo | Cold Drinks & Juices',
#  "L1: sid's farm buttermilk | Cold Drinks & Juices",
#  'L1: amul masti spiced buttermilk 1 l combo | Cold Drinks & Juices',
#  'L1: natraj big/large cutter | Stationery & Books',
#  'L1: stanley 10-143-s  basic snap-off blade knife 18 mm, ideal for light-duty cutting & trimming | Stationery & Books',
#  'L1: abk box cutter - 25 mm black/yellow- heavy duty | Stationery & Books',
#  'L1: stanley stht10323-800 18mm plastic slide lock snap-off knife for home & professional use, yellow | Stationery & Books',
#  'L1: surf excel 3 in 1 smart shots | pack of 17 for front load & top load washing machines|(17 u x 21 g) | Cleaning Essentials',
#  'L1: surf excel 3in1 smart shots | pack of 28 for front load & top load washing machines | (28u x21g) | Cleaning Essentials',
#  'L1: surf excel matic 3 in 1 detergent pods | Cleaning Essentials',
#  'L1: mtr 3 min poha | Packaged Food',
#  ...]

# %%
import torch
from tqdm import tqdm

def generate_embeddings(text_list, tokenizer, model, batch_size=32, max_length=128):
    embeddings = []
    model.eval()

    with torch.no_grad():
        for i in tqdm(range(0, len(text_list), batch_size)):
            batch_texts = text_list[i:i+batch_size]
            encoded = tokenizer(
                batch_texts,
                return_tensors="pt",
                padding=True,
                truncation=True,
                max_length=max_length
            )

            input_ids = encoded["input_ids"].to(model.device)
            attention_mask = encoded["attention_mask"].to(model.device)

            outputs = model.base_model.base_model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                output_hidden_states=True,
                return_dict=True
            )
            cls_embeddings = outputs.last_hidden_state[:, 0, :]


            cls_embeddings = outputs.last_hidden_state[:, 0, :]  # Use [CLS] token
            embeddings.append(cls_embeddings.cpu())

    return torch.cat(embeddings, dim=0)

# %%
l1_embeddings = generate_embeddings(
    text_list=l1_inputs,
    tokenizer=tokenizer,
    model=model,
    batch_size=32
)
# Out:
# 100%|██████████| 242/242 [15:45<00:00,  3.91s/it]

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 15.9 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0

# %%
import faiss
import numpy as np

# Normalize for cosine similarity
l1_embeddings_np = l1_embeddings.numpy()
# l1_embeddings_np= np.load("/content/drive/MyDrive/Zepto IDC Query Classification/l1_from_fine_tuned.npy")
l1_embeddings_np = l1_embeddings_np / np.linalg.norm(l1_embeddings_np, axis=1, keepdims=True)

# Build FAISS index
index = faiss.IndexFlatIP(l1_embeddings_np.shape[1])
index.add(l1_embeddings_np)

# %%
l1_

# %%
def retrieve_top_k(query, k=10):
    formatted = f"L1: {query}"
    query_emb = generate_embeddings([formatted], tokenizer, model)
    query_emb = query_emb / query_emb.norm(dim=1, keepdim=True)  # Normalize

    D, I = index.search(query_emb.numpy(), k)  # FAISS expects np
    results = [(l1_inputs[i], float(D[0][rank])) for rank, i in enumerate(I[0])]
    return results

# %%
import pandas as pd

df = pd.DataFrame(l1_inputs)
df.to_csv("/content/drive/MyDrive/Zepto IDC Query Classification/l1_inputs.csv", index=False)

# %%
query = "sri sri ghee"
top_results = retrieve_top_k(query, k=10)

print(f"\nTop results for: '{query}'")
for score_pair in top_results:
    print(f"[{score_pair[1]:.4f}] {score_pair[0]}")
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  6.19it/s]
# Top results for: 'sri sri ghee'
# [0.7246] L1: namaskaram bhavnagri gathiya | Munchies
# [0.7197] L1: veerabhadra green batana | Munchies
# [0.7195] L1: namaskaram surti gathiya | Munchies
# [0.7132] L1: namaskaram roasted yellow chana | Munchies
# [0.7125] L1: veerabhadra namkeen | Munchies
# [0.7099] L1: veerabhadra chakodi | Munchies
# [0.7097] L1: too yumm! aloo bhujia | no palm oil | 35% less saturated fat | Munchies
# [0.7072] L1: gopal namkeen dal moth | Munchies
# [0.7071] L1: namaskaram masala chana dal | Munchies
# [0.7058] L1: gwalia bhatha kani | Munchies
